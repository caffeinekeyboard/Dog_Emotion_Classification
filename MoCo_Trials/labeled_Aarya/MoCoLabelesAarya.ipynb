# %% [markdown]
# #### Implementation of Momentum Contrast for Unsupervised Visual Representation Learning, to analyse and detect dog emotions.
# - Paper : https://arxiv.org/abs/1911.05722
# - Code : https://github.com/facebookresearch/moco

# %%
import logging
import os 
import random
from functools import partial

import torch
from PIL import ImageFilter
from torchvision import datasets, transforms
from torchvision.models import resnet 
from tqdm import tqdm 
import numpy as np

from pytorch_metric_learning import losses
from pytorch_metric_learning.utils import logging_presets

logging.getLogger().setLevel(logging.INFO)

device = torch.device("cuda")

# %% [markdown]
# ##### Augmentation functions taken straight from https://github.com/facebookresearch/moco
# - Two-Crops Transform
# - Gaussian Blur

# %%
class TwoCropsTransform:
    """Take two random crops of one image as the query and key."""

    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        q = self.base_transform(x)
        k = self.base_transform(x)
        return [q, k]
    
class GaussianBlur(object):
    """Gaussian blur augmentation in SimCLR https://arxiv.org/abs/2002.05709"""

    def __init__(self, sigma=[0.1, 2.0]):
        self.sigma = sigma

    def __call__(self, x):
        sigma = random.uniform(self.sigma[0], self.sigma[1])
        x = x.filter(ImageFilter.GaussianBlur(radius=sigma))
        return x

# %% [markdown]
# ##### Dataset creation function.
# - Reduces overhead variable accumulation.
# - Easy to steal from MoCo :-)

# %%
MEAN = [0.47365573, 0.4402452, 0.38663769]
STD = [0.26914782, 0.26083042, 0.2624779]

# %%
def create_dataset(batch_size):
    normalize = transforms.Normalize(MEAN, STD)
    
    train_transform = transforms.Compose(
        [
            transforms.RandomResizedCrop(32),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
            transforms.RandomGrayscale(p=0.2),
            transforms.ToTensor(),
            normalize,
        ]
    )

    train_transform = TwoCropsTransform(train_transform)
    val_transform = transforms.Compose([transforms.Resize((32, 32)), transforms.ToTensor(), normalize])
    
    train_dir = 'data/train/'
    val_dir = 'data/validation/'
    test_dir = 'data/test/'
    
    train_dataset = datasets.ImageFolder(
        train_dir , transform=train_transform
    )
    train_dataset_for_eval = datasets.ImageFolder(
        val_dir, transform=val_transform
    )
    val_dataset = datasets.ImageFolder(
        test_dir, transform=val_transform
    )

    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True,
        drop_last=True,
    )

    train_loader_for_eval = torch.utils.data.DataLoader(
        train_dataset_for_eval,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    return (
        train_dataset,
        train_dataset_for_eval,
        val_dataset,
        train_loader,
        train_loader_for_eval,
        val_loader,
    )

# %% [markdown]
# ##### SplitBatchNorm: simulate multi-gpu behavior of BatchNorm in one gpu by splitting alone the batch dimension.
# - Yanked from https://github.com/davidcpage/cifar10-fast/blob/master/torch_backend.py

# %%
class SplitBatchNorm(torch.nn.BatchNorm2d):
    def __init__(self, num_features, num_splits, **kw):
        super().__init__(num_features, **kw)
        self.num_splits = num_splits

    def forward(self, input):
        N, C, H, W = input.shape
        if self.training or not self.track_running_stats:
            running_mean_split = self.running_mean.repeat(self.num_splits)
            running_var_split = self.running_var.repeat(self.num_splits)
            outcome = torch.nn.functional.batch_norm(
                input.view(-1, C * self.num_splits, H, W),
                running_mean_split,
                running_var_split,
                self.weight.repeat(self.num_splits),
                self.bias.repeat(self.num_splits),
                True,
                self.momentum,
                self.eps,
            ).view(N, C, H, W)
            self.running_mean.data.copy_(
                running_mean_split.view(self.num_splits, C).mean(dim=0)
            )
            self.running_var.data.copy_(
                running_var_split.view(self.num_splits, C).mean(dim=0)
            )
            return outcome
        else:
            return torch.nn.functional.batch_norm(
                input,
                self.running_mean,
                self.running_var,
                self.weight,
                self.bias,
                False,
                self.momentum,
                self.eps,
            )

# %% [markdown]
# ##### Model definition and code for copying params from encQ to encK.

# %%
class ModelBase(torch.nn.Module):
    """
    Common CIFAR ResNet recipe.
    Comparing with ImageNet ResNet recipe, it:
    (i) replaces conv1 with kernel=3, str=1
    (ii) removes pool1
    """

    def __init__(self, feature_dim=128, arch="resnet18", bn_splits=8):
        super(ModelBase, self).__init__()

        # use split batchnorm
        norm_layer = (
            partial(SplitBatchNorm, num_splits=bn_splits)
            if bn_splits > 1
            else torch.nn.BatchNorm2d
        )
        resnet_arch = getattr(resnet, arch)
        net = resnet_arch(num_classes=feature_dim, norm_layer=norm_layer)

        self.net = []
        for name, module in net.named_children():
            if name == "conv1":
                module = torch.nn.Conv2d(
                    3, 64, kernel_size=3, stride=1, padding=1, bias=False
                )
            if isinstance(module, torch.nn.MaxPool2d):
                continue
            if isinstance(module, torch.nn.Linear):
                self.net.append(torch.nn.Flatten(1))
            self.net.append(module)

        self.net = torch.nn.Sequential(*self.net)

    def forward(self, x):
        x = self.net(x)
        # note: not normalized here
        return x


def copy_params(encQ, encK, m=None):
    if m is None:
        for param_q, param_k in zip(encQ.parameters(), encK.parameters()):
            param_k.data.copy_(param_q.data)  # initialize
            param_k.requires_grad = False  # not update by gradient
    else:
        for param_q, param_k in zip(encQ.parameters(), encK.parameters()):
            param_k.data = param_k.data * m + param_q.data * (1.0 - m)


def create_encoder():
    model = ModelBase()
    model = torch.nn.DataParallel(model)
    model.to(device)
    return model

# %% [markdown]
# ##### Evaluation Functions.

# %%
def test(net, memory_data_loader, test_data_loader, epoch, knn_k, knn_t, record_keeper):
    net.eval()
    classes = len(memory_data_loader.dataset.classes)
    total_top1, total_num, feature_bank = 0.0, 0, []
    with torch.no_grad():
        # generate feature bank
        for data, target in tqdm(memory_data_loader, desc="Feature extracting"):
            feature = net(data.cuda(non_blocking=True))
            feature = torch.nn.functional.normalize(feature, dim=1)
            feature_bank.append(feature)
        # [D, N]
        feature_bank = torch.cat(feature_bank, dim=0).t().contiguous()
        # [N]
        feature_labels = torch.tensor(
            memory_data_loader.dataset.targets, device=feature_bank.device
        )
        # loop test data to predict the label by weighted knn search
        test_bar = tqdm(test_data_loader)
        for data, target in test_bar:
            data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            feature = net(data)
            feature = torch.nn.functional.normalize(feature, dim=1)

            pred_labels = knn_predict(
                feature, feature_bank, feature_labels, classes, knn_k, knn_t
            )

            total_num += data.size(0)
            total_top1 += (pred_labels[:, 0] == target).float().sum().item()
            acc = total_top1 / total_num * 100
            test_bar.set_description("Test Epoch {}: Acc@1:{:.2f}%".format(epoch, acc))

    record_keeper.update_records(
        {"knn_monitor_accuracy": acc},
        epoch,
        parent_name="accuracy",
    )
    record_keeper.save_records()
    return acc


def knn_predict(feature, feature_bank, feature_labels, classes, knn_k, knn_t):
    # compute cos similarity between each feature vector and feature bank ---> [B, N]
    sim_matrix = torch.mm(feature, feature_bank)
    # [B, K]
    sim_weight, sim_indices = sim_matrix.topk(k=knn_k, dim=-1)
    # [B, K]
    sim_labels = torch.gather(
        feature_labels.expand(feature.size(0), -1), dim=-1, index=sim_indices
    )
    sim_weight = (sim_weight / knn_t).exp()

    # counts for each class
    one_hot_label = torch.zeros(
        feature.size(0) * knn_k, classes, device=sim_labels.device
    )
    # [B*K, C]
    one_hot_label = one_hot_label.scatter(
        dim=-1, index=sim_labels.view(-1, 1), value=1.0
    )
    # weighted score ---> [B, C]
    pred_scores = torch.sum(
        one_hot_label.view(feature.size(0), -1, classes) * sim_weight.unsqueeze(dim=-1),
        dim=1,
    )

    pred_labels = pred_scores.argsort(dim=-1, descending=True)
    return pred_labels

# %% [markdown]
# ##### Training and logging functions.

# %%
def update_records(loss, loss_fn, optimizer, record_keeper, global_iteration):
    def optimizer_custom_attr_func(opt):
        return {"lr": opt.param_groups[0]["lr"]}

    record_these = [
        [{"loss": loss.item()}, {"parent_name": "loss_histories"}],
        [{"loss_function": loss_fn}, {"recursive_types": [torch.nn.Module]}],
        [{"optimizer": optimizer}, {"custom_attr_func": optimizer_custom_attr_func}],
    ]
    for record, kwargs in record_these:
        record_keeper.update_records(record, global_iteration, **kwargs)


def save_model(encQ):
    model_folder = "example_saved_models"
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)
    torch.save(encQ.state_dict(), "{}/encQ_best.pth".format(model_folder))



def batch_shuffle_single_gpu(x):
    """
    Batch shuffle, for making use of BatchNorm.
    """
    # random shuffle index
    idx_shuffle = torch.randperm(x.shape[0]).cuda()

    # index for restoring
    idx_unshuffle = torch.argsort(idx_shuffle)

    return x[idx_shuffle], idx_unshuffle



def batch_unshuffle_single_gpu(x, idx_unshuffle):
    """
    Undo batch shuffle.
    """
    return x[idx_unshuffle]


def create_labels(num_pos_pairs, previous_max_label):
    # create labels that indicate what the positive pairs are
    labels = torch.arange(0, num_pos_pairs)
    labels = torch.cat((labels, labels)).to(device)
    # add an offset so that the labels do not overlap with any labels in the memory queue
    labels += previous_max_label + 1
    # we want to enqueue the output of encK, which is the 2nd half of the batch
    enqueue_mask = torch.zeros(len(labels)).bool()
    enqueue_mask[num_pos_pairs:] = True
    return labels, enqueue_mask


def train(
    encQ,
    encK,
    paramK_momentum,
    loss_fn,
    optimizer,
    train_loader,
    record_keeper,
    global_iteration,
):
    encQ.train()
    pbar = tqdm(train_loader)
    for images, _ in pbar:
        previous_max_label = torch.max(loss_fn.label_memory)
        imgQ = images[0].to(device)
        imgK = images[1].to(device)

        # compute output
        encQ_out = encQ(imgQ)
        with torch.no_grad():  # no gradient to keys
            copy_params(encQ, encK, m=paramK_momentum)
            imgK, idx_unshuffle = batch_shuffle_single_gpu(imgK)
            encK_out = encK(imgK)
            encK_out = batch_unshuffle_single_gpu(encK_out, idx_unshuffle)

        all_enc = torch.cat([encQ_out, encK_out], dim=0)
        labels, enqueue_mask = create_labels(encQ_out.size(0), previous_max_label)
        loss = loss_fn(all_enc, labels, enqueue_mask=enqueue_mask)

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pbar.set_description("loss=%.5f" % loss.item())
        update_records(
            loss, loss_fn, optimizer, record_keeper, global_iteration["iter"]
        )
        global_iteration["iter"] += 1

# %% [markdown]
# ##### Start Tensorboard and delete old folders.

# %%
# !rm -rfv example_logs example_tensorboard example_saved_models
# %load_ext tensorboard
# %tensorboard --logdir example_tensorboard
# Out:
#       <iframe id="tensorboard-frame-4ec45161f327ac15" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4ec45161f327ac15");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
batch_size = 256
lr = 0.03
paramK_momentum = 0.99
memory_size = 4096
num_epochs = 200
knn_k = 200
knn_t = 0.1

(
    train_dataset,
    train_dataset_for_eval,
    val_dataset,
    train_loader,
    train_loader_for_eval,
    val_loader,
) = create_dataset(batch_size)

encQ = create_encoder()
encK = create_encoder()

# copy params from encQ into encK
copy_params(encQ, encK)

optimizer = torch.optim.SGD(encQ.parameters(), lr, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_epochs)

###########################################################
### Set the loss function and the (optional) miner here ###
###########################################################
loss_fn = losses.CrossBatchMemory(
    loss=losses.NTXentLoss(temperature=0.1), embedding_size=128, memory_size=memory_size
)

dataset_dict = {"train": train_dataset_for_eval, "val": val_dataset}
record_keeper, _, _ = logging_presets.get_record_keeper(
    "example_logs", "example_tensorboard"
)
hooks = logging_presets.get_hook_container(record_keeper)

# first check untrained performance
epoch = 0
best_accuracy = test(
    encQ, train_loader_for_eval, val_loader, epoch, knn_k, knn_t, record_keeper
)

global_iteration = {"iter": 0}
for epoch in range(1, num_epochs + 1):
    logging.info("Starting epoch {}".format(epoch))
    train(
        encQ,
        encK,
        paramK_momentum,
        loss_fn,
        optimizer,
        train_loader,
        record_keeper,
        global_iteration,
    )
    curr_accuracy = test(
        encQ, train_loader_for_eval, val_loader, epoch, knn_k, knn_t, record_keeper
    )
    if curr_accuracy > best_accuracy:
        best_accuracy = curr_accuracy
        save_model(encQ)
    scheduler.step()
# Out:
# Feature extracting: 100%|██████████| 2/2 [00:03<00:00,  1.97s/it]
# Test Epoch 0: Acc@1:14.61%: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# INFO:root:Starting epoch 1
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=7.10009: 100%|██████████| 5/5 [00:09<00:00,  1.97s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.50s/it]
# Test Epoch 1: Acc@1:19.77%: 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# INFO:root:Starting epoch 2
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=7.65731: 100%|██████████| 5/5 [00:10<00:00,  2.17s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.46s/it]
# Test Epoch 2: Acc@1:16.62%: 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]
# INFO:root:Starting epoch 3
# loss=7.78663: 100%|██████████| 5/5 [00:13<00:00,  2.72s/it]
# Feature extracting: 100%|██████████| 2/2 [00:03<00:00,  1.65s/it]
# Test Epoch 3: Acc@1:15.47%: 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]
# INFO:root:Starting epoch 4
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=7.60866: 100%|██████████| 5/5 [00:14<00:00,  2.86s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
# Test Epoch 4: Acc@1:15.19%: 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]
# INFO:root:Starting epoch 5
# loss=7.55669:  20%|██        | 1/5 [00:05<00:21,  5.34s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=7.32896: 100%|██████████| 5/5 [00:14<00:00,  2.81s/it]
# Feature extracting: 100%|██████████| 2/2 [00:03<00:00,  1.64s/it]
# Test Epoch 5: Acc@1:20.34%: 100%|██████████| 2/2 [00:02<00:00,  1.41s/it]
# INFO:root:Starting epoch 6
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=7.07878: 100%|██████████| 5/5 [00:15<00:00,  3.03s/it]
# Feature extracting: 100%|██████████| 2/2 [00:03<00:00,  1.62s/it]
# Test Epoch 6: Acc@1:18.05%: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# INFO:root:Starting epoch 7
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.85413: 100%|██████████| 5/5 [00:15<00:00,  3.07s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.17s/it]
# Test Epoch 7: Acc@1:20.63%: 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
# INFO:root:Starting epoch 8
# loss=6.72635: 100%|██████████| 5/5 [00:13<00:00,  2.67s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]
# Test Epoch 8: Acc@1:21.20%: 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# INFO:root:Starting epoch 9
# loss=6.79004:  20%|██        | 1/5 [00:04<00:18,  4.60s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.70605: 100%|██████████| 5/5 [00:13<00:00,  2.78s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# Test Epoch 9: Acc@1:20.92%: 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]
# INFO:root:Starting epoch 10
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.63722: 100%|██████████| 5/5 [00:15<00:00,  3.10s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Test Epoch 10: Acc@1:19.20%: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# INFO:root:Starting epoch 11
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.49312: 100%|██████████| 5/5 [00:13<00:00,  2.71s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Test Epoch 11: Acc@1:20.63%: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# INFO:root:Starting epoch 12
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.60600: 100%|██████████| 5/5 [00:14<00:00,  2.81s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Test Epoch 12: Acc@1:18.34%: 100%|██████████| 2/2 [00:02<00:00,  1.42s/it]
# INFO:root:Starting epoch 13
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.50276: 100%|██████████| 5/5 [00:14<00:00,  2.86s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# Test Epoch 13: Acc@1:20.06%: 100%|██████████| 2/2 [00:02<00:00,  1.35s/it]
# INFO:root:Starting epoch 14
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.54787: 100%|██████████| 5/5 [00:13<00:00,  2.74s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.35s/it]
# Test Epoch 14: Acc@1:19.20%: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# INFO:root:Starting epoch 15
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.59356: 100%|██████████| 5/5 [00:14<00:00,  2.89s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# Test Epoch 15: Acc@1:18.62%: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# INFO:root:Starting epoch 16
# loss=6.55521: 100%|██████████| 5/5 [00:13<00:00,  2.70s/it]
# Feature extracting: 100%|██████████| 2/2 [00:03<00:00,  1.57s/it]
# Test Epoch 16: Acc@1:17.48%: 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
# INFO:root:Starting epoch 17
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.41564: 100%|██████████| 5/5 [00:15<00:00,  3.10s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Test Epoch 17: Acc@1:21.49%: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# INFO:root:Starting epoch 18
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43030: 100%|██████████| 5/5 [00:13<00:00,  2.62s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Test Epoch 18: Acc@1:19.77%: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# INFO:root:Starting epoch 19
# loss=6.52110:  20%|██        | 1/5 [00:05<00:20,  5.09s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.37376: 100%|██████████| 5/5 [00:14<00:00,  2.90s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Test Epoch 19: Acc@1:18.05%: 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]
# INFO:root:Starting epoch 20
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43358: 100%|██████████| 5/5 [00:14<00:00,  2.89s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it]
# Test Epoch 20: Acc@1:21.20%: 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
# INFO:root:Starting epoch 21
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.36441: 100%|██████████| 5/5 [00:14<00:00,  2.88s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# Test Epoch 21: Acc@1:19.20%: 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]
# INFO:root:Starting epoch 22
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.44213: 100%|██████████| 5/5 [00:13<00:00,  2.74s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.35s/it]
# Test Epoch 22: Acc@1:20.06%: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# INFO:root:Starting epoch 23
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.39293: 100%|██████████| 5/5 [00:14<00:00,  2.91s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Test Epoch 23: Acc@1:19.48%: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# INFO:root:Starting epoch 24
# loss=6.38992: 100%|██████████| 5/5 [00:15<00:00,  3.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.27s/it]
# Test Epoch 24: Acc@1:18.05%: 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]
# INFO:root:Starting epoch 25
# loss=6.28772: 100%|██████████| 5/5 [00:13<00:00,  2.74s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Test Epoch 25: Acc@1:19.48%: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# INFO:root:Starting epoch 26
# loss=6.43089:  20%|██        | 1/5 [00:04<00:18,  4.62s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.42572: 100%|██████████| 5/5 [00:14<00:00,  2.89s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Test Epoch 26: Acc@1:21.78%: 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]
# INFO:root:Starting epoch 27
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.44425: 100%|██████████| 5/5 [00:13<00:00,  2.73s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Test Epoch 27: Acc@1:21.20%: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# INFO:root:Starting epoch 28
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.34030: 100%|██████████| 5/5 [00:13<00:00,  2.68s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]
# Test Epoch 28: Acc@1:23.50%: 100%|██████████| 2/2 [00:02<00:00,  1.43s/it]
# INFO:root:Starting epoch 29
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.32705: 100%|██████████| 5/5 [00:14<00:00,  2.98s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]
# Test Epoch 29: Acc@1:20.63%: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# INFO:root:Starting epoch 30
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.41109: 100%|██████████| 5/5 [00:14<00:00,  2.98s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Test Epoch 30: Acc@1:20.63%: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# INFO:root:Starting epoch 31
# loss=6.35385: 100%|██████████| 5/5 [00:14<00:00,  2.85s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.35s/it]
# Test Epoch 31: Acc@1:22.64%: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# INFO:root:Starting epoch 32
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.29211: 100%|██████████| 5/5 [00:14<00:00,  2.81s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Test Epoch 32: Acc@1:22.35%: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# INFO:root:Starting epoch 33
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.34404: 100%|██████████| 5/5 [00:14<00:00,  2.97s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Test Epoch 33: Acc@1:19.48%: 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]
# INFO:root:Starting epoch 34
# loss=6.38654: 100%|██████████| 5/5 [00:13<00:00,  2.62s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.25s/it]
# Test Epoch 34: Acc@1:21.78%: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# INFO:root:Starting epoch 35
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.31666: 100%|██████████| 5/5 [00:16<00:00,  3.37s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.26s/it]
# Test Epoch 35: Acc@1:22.64%: 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]
# INFO:root:Starting epoch 36
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.37760: 100%|██████████| 5/5 [00:14<00:00,  2.88s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]
# Test Epoch 36: Acc@1:20.63%: 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]
# INFO:root:Starting epoch 37
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.19031: 100%|██████████| 5/5 [00:14<00:00,  2.83s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.38s/it]
# Test Epoch 37: Acc@1:21.49%: 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]
# INFO:root:Starting epoch 38
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.48774: 100%|██████████| 5/5 [00:13<00:00,  2.80s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.38s/it]
# Test Epoch 38: Acc@1:20.63%: 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# INFO:root:Starting epoch 39
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.39028: 100%|██████████| 5/5 [00:13<00:00,  2.73s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# Test Epoch 39: Acc@1:19.20%: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# INFO:root:Starting epoch 40
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38489: 100%|██████████| 5/5 [00:13<00:00,  2.70s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# Test Epoch 40: Acc@1:22.92%: 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
# INFO:root:Starting epoch 41
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.28381: 100%|██████████| 5/5 [00:12<00:00,  2.57s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.28s/it]
# Test Epoch 41: Acc@1:22.92%: 100%|██████████| 2/2 [00:02<00:00,  1.40s/it]
# INFO:root:Starting epoch 42
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.39896: 100%|██████████| 5/5 [00:13<00:00,  2.66s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Test Epoch 42: Acc@1:22.92%: 100%|██████████| 2/2 [00:02<00:00,  1.44s/it]
# INFO:root:Starting epoch 43
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.34013: 100%|██████████| 5/5 [00:13<00:00,  2.63s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Test Epoch 43: Acc@1:22.64%: 100%|██████████| 2/2 [00:02<00:00,  1.45s/it]
# INFO:root:Starting epoch 44
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.33584: 100%|██████████| 5/5 [00:10<00:00,  2.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Test Epoch 44: Acc@1:20.92%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 45
# loss=6.36046:  40%|████      | 2/5 [00:02<00:03,  1.09s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.34296: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 45: Acc@1:22.92%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 46
# loss=6.36595:  40%|████      | 2/5 [00:02<00:02,  1.01it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.34891: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 46: Acc@1:21.78%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 47
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43752: 100%|██████████| 5/5 [00:06<00:00,  1.23s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 47: Acc@1:22.92%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 48
# loss=6.45556: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 48: Acc@1:21.78%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 49
# loss=6.44321: 100%|██████████| 5/5 [00:05<00:00,  1.07s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Test Epoch 49: Acc@1:24.64%: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# INFO:root:Starting epoch 50
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38934: 100%|██████████| 5/5 [00:06<00:00,  1.24s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Test Epoch 50: Acc@1:21.78%: 100%|██████████| 2/2 [00:02<00:00,  1.03s/it]
# INFO:root:Starting epoch 51
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.42799: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 51: Acc@1:23.21%: 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
# INFO:root:Starting epoch 52
# loss=6.31186:  20%|██        | 1/5 [00:02<00:08,  2.25s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.48597: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 52: Acc@1:22.64%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 53
# loss=6.44391:  40%|████      | 2/5 [00:01<00:02,  1.23it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43896: 100%|██████████| 5/5 [00:06<00:00,  1.21s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 53: Acc@1:23.21%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 54
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.45792: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 54: Acc@1:24.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 55
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.36012: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 55: Acc@1:21.20%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 56
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43835: 100%|██████████| 5/5 [00:05<00:00,  1.17s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 56: Acc@1:22.64%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 57
# loss=6.55847:  40%|████      | 2/5 [00:02<00:03,  1.09s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38257: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 57: Acc@1:22.92%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 58
# loss=6.43782: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Test Epoch 58: Acc@1:23.50%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 59
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.42103: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 59: Acc@1:24.93%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 60
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.39515: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 60: Acc@1:23.21%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 61
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.39553: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 61: Acc@1:22.64%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 62
# loss=6.37480:  40%|████      | 2/5 [00:02<00:03,  1.19s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43652: 100%|██████████| 5/5 [00:05<00:00,  1.20s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 62: Acc@1:23.21%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 63
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.35886: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 63: Acc@1:23.50%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 64
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38616: 100%|██████████| 5/5 [00:06<00:00,  1.23s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 64: Acc@1:22.64%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 65
# loss=6.42338:  80%|████████  | 4/5 [00:04<00:00,  1.11it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.50930: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 65: Acc@1:21.49%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 66
# loss=6.39208:  40%|████      | 2/5 [00:02<00:02,  1.07it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.44651: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 66: Acc@1:22.92%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 67
# loss=6.43614:  80%|████████  | 4/5 [00:04<00:00,  1.21it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.34802: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 67: Acc@1:25.79%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 68
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43347: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 68: Acc@1:25.50%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 69
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.51626: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 69: Acc@1:23.78%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 70
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.44838: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 70: Acc@1:23.21%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 71
# loss=6.43309:  40%|████      | 2/5 [00:02<00:03,  1.06s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.47921: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 71: Acc@1:22.35%: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# INFO:root:Starting epoch 72
# loss=6.47772:  40%|████      | 2/5 [00:02<00:03,  1.01s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.25495: 100%|██████████| 5/5 [00:05<00:00,  1.06s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 72: Acc@1:24.36%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 73
# loss=6.32606:  40%|████      | 2/5 [00:02<00:03,  1.15s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.40030: 100%|██████████| 5/5 [00:06<00:00,  1.25s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 73: Acc@1:24.93%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 74
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.39877: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 74: Acc@1:22.92%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 75
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.49439: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 75: Acc@1:23.50%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 76
# loss=6.44206:  40%|████      | 2/5 [00:02<00:02,  1.08it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.47739: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 76: Acc@1:23.21%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 77
# loss=6.57527:  60%|██████    | 3/5 [00:03<00:02,  1.05s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43826: 100%|██████████| 5/5 [00:06<00:00,  1.29s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 77: Acc@1:23.21%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 78
# loss=6.46535:  60%|██████    | 3/5 [00:03<00:01,  1.04it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.29924: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 78: Acc@1:24.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 79
# loss=6.36288:  80%|████████  | 4/5 [00:04<00:00,  1.07it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.54424: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 79: Acc@1:24.64%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 80
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.36340: 100%|██████████| 5/5 [00:05<00:00,  1.20s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 80: Acc@1:27.22%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 81
# loss=6.35851:  40%|████      | 2/5 [00:02<00:02,  1.01it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.26853: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 81: Acc@1:25.50%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 82
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.44183: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 82: Acc@1:22.64%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 83
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43866: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Test Epoch 83: Acc@1:24.64%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 84
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.31481: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 84: Acc@1:22.64%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 85
# loss=6.40466:  20%|██        | 1/5 [00:01<00:07,  1.85s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38006: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 85: Acc@1:25.79%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 86
# loss=6.39005: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 86: Acc@1:28.65%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 87
# loss=6.23213:  40%|████      | 2/5 [00:02<00:03,  1.08s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.47830: 100%|██████████| 5/5 [00:05<00:00,  1.00s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 87: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 88
# loss=6.37880:  40%|████      | 2/5 [00:02<00:03,  1.05s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.55792: 100%|██████████| 5/5 [00:06<00:00,  1.27s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 88: Acc@1:26.65%: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# INFO:root:Starting epoch 89
# loss=6.28089:  40%|████      | 2/5 [00:02<00:02,  1.08it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.52209: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.34s/it]
# Test Epoch 89: Acc@1:24.64%: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# INFO:root:Starting epoch 90
# loss=6.41334:  60%|██████    | 3/5 [00:03<00:02,  1.07s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.25315: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 90: Acc@1:24.93%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 91
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43438: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Test Epoch 91: Acc@1:23.78%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 92
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.51365: 100%|██████████| 5/5 [00:06<00:00,  1.22s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 92: Acc@1:24.07%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 93
# loss=6.26866:  20%|██        | 1/5 [00:02<00:09,  2.36s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.54627: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 93: Acc@1:23.50%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 94
# loss=6.34869:  40%|████      | 2/5 [00:03<00:04,  1.46s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.34630: 100%|██████████| 5/5 [00:06<00:00,  1.29s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 94: Acc@1:24.64%: 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]
# INFO:root:Starting epoch 95
# loss=6.40043: 100%|██████████| 5/5 [00:05<00:00,  1.00s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 95: Acc@1:25.21%: 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
# INFO:root:Starting epoch 96
# loss=6.30109:  40%|████      | 2/5 [00:03<00:04,  1.38s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.36373: 100%|██████████| 5/5 [00:08<00:00,  1.63s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 96: Acc@1:23.21%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 97
# loss=6.54568:  40%|████      | 2/5 [00:02<00:03,  1.04s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38092: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 97: Acc@1:24.64%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 98
# loss=6.40739:  80%|████████  | 4/5 [00:04<00:00,  1.12it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.27042: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 98: Acc@1:25.50%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 99
# loss=6.37781:  40%|████      | 2/5 [00:02<00:03,  1.09s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.32062: 100%|██████████| 5/5 [00:06<00:00,  1.20s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 99: Acc@1:25.50%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 100
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.40176: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 100: Acc@1:24.93%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 101
# loss=6.32848:  20%|██        | 1/5 [00:02<00:09,  2.35s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.45165: 100%|██████████| 5/5 [00:05<00:00,  1.17s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 101: Acc@1:24.07%: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# INFO:root:Starting epoch 102
# loss=6.24977:  80%|████████  | 4/5 [00:04<00:00,  1.13it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.27993: 100%|██████████| 5/5 [00:06<00:00,  1.20s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 102: Acc@1:24.93%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 103
# loss=6.32160:  40%|████      | 2/5 [00:02<00:03,  1.12s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.45746: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 103: Acc@1:23.78%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 104
# loss=6.19696:  40%|████      | 2/5 [00:02<00:03,  1.02s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38409: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 104: Acc@1:25.50%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 105
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.28849: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 105: Acc@1:24.64%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 106
# loss=6.32142:  80%|████████  | 4/5 [00:04<00:00,  1.17it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.23185: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 106: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 107
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.29604: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 107: Acc@1:24.93%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 108
# ...
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 165: Acc@1:26.65%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 166
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.27012: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 166: Acc@1:25.79%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 167
# loss=6.13268: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 167: Acc@1:24.93%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 168
# loss=6.31526:  40%|████      | 2/5 [00:02<00:03,  1.12s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.41717: 100%|██████████| 5/5 [00:05<00:00,  1.06s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 168: Acc@1:25.79%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 169
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.23625: 100%|██████████| 5/5 [00:05<00:00,  1.12s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 169: Acc@1:26.36%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 170
# loss=6.17918:  80%|████████  | 4/5 [00:04<00:00,  1.01it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.40906: 100%|██████████| 5/5 [00:06<00:00,  1.20s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 170: Acc@1:26.36%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 171
# loss=6.28350:  40%|████      | 2/5 [00:02<00:03,  1.18s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.27878: 100%|██████████| 5/5 [00:06<00:00,  1.21s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.33s/it]
# Test Epoch 171: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 172
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.27283: 100%|██████████| 5/5 [00:05<00:00,  1.20s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 172: Acc@1:26.36%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 173
# loss=6.42336: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 173: Acc@1:27.79%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 174
# loss=6.26523:  20%|██        | 1/5 [00:01<00:07,  1.77s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.13073: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 174: Acc@1:27.51%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 175
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.36747: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 175: Acc@1:26.65%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 176
# loss=6.29162:  40%|████      | 2/5 [00:02<00:02,  1.05it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.36638: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 176: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 177
# loss=6.55555:  40%|████      | 2/5 [00:02<00:03,  1.06s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.24970: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 177: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 178
# loss=6.38864:  40%|████      | 2/5 [00:02<00:02,  1.13it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.42956: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 178: Acc@1:24.93%: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# INFO:root:Starting epoch 179
# loss=6.34561:  40%|████      | 2/5 [00:02<00:03,  1.21s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.40598: 100%|██████████| 5/5 [00:05<00:00,  1.17s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 179: Acc@1:25.79%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 180
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43980: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 180: Acc@1:25.79%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 181
# loss=6.32777:  40%|████      | 2/5 [00:02<00:03,  1.01s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.37538: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 181: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 182
# loss=6.20965:  20%|██        | 1/5 [00:02<00:08,  2.02s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38846: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 182: Acc@1:26.65%: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# INFO:root:Starting epoch 183
# loss=6.35541: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 183: Acc@1:26.36%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 184
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43483: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 184: Acc@1:26.36%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 185
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.52871: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 185: Acc@1:26.07%: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# INFO:root:Starting epoch 186
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.43920: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 186: Acc@1:26.65%: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# INFO:root:Starting epoch 187
# loss=6.22243:  80%|████████  | 4/5 [00:04<00:00,  1.16it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.45011: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 187: Acc@1:26.36%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 188
# loss=6.32807:  40%|████      | 2/5 [00:02<00:03,  1.07s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.46885: 100%|██████████| 5/5 [00:06<00:00,  1.22s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 188: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 189
# loss=6.43654:  40%|████      | 2/5 [00:02<00:03,  1.09s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.42622: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 189: Acc@1:26.07%: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# INFO:root:Starting epoch 190
# loss=6.56842:  20%|██        | 1/5 [00:01<00:06,  1.73s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.59435: 100%|██████████| 5/5 [00:06<00:00,  1.36s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 190: Acc@1:26.07%: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# INFO:root:Starting epoch 191
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.45039: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 191: Acc@1:25.79%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 192
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.45245: 100%|██████████| 5/5 [00:09<00:00,  1.90s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 192: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 193
# loss=6.58555: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 193: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 194
# loss=6.45871:  40%|████      | 2/5 [00:02<00:02,  1.01it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.45307: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 194: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 195
#   0%|          | 0/5 [00:00<?, ?it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.35631: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 195: Acc@1:25.79%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 196
# loss=6.52307:  40%|████      | 2/5 [00:02<00:03,  1.07s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.34672: 100%|██████████| 5/5 [00:06<00:00,  1.23s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 196: Acc@1:26.07%: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# INFO:root:Starting epoch 197
# loss=6.42722:  40%|████      | 2/5 [00:02<00:03,  1.01s/it]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.38424: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 197: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 198
# loss=6.45358:  80%|████████  | 4/5 [00:04<00:00,  1.18it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.46069: 100%|██████████| 5/5 [00:06<00:00,  1.23s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 198: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 199
# loss=6.33943:  40%|████      | 2/5 [00:02<00:02,  1.02it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.30378: 100%|██████████| 5/5 [00:05<00:00,  1.10s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 199: Acc@1:26.07%: 100%|██████████| 2/2 [00:01<00:00,  1.00it/s]
# INFO:root:Starting epoch 200
# loss=6.74747:  80%|████████  | 4/5 [00:03<00:00,  1.29it/s]/home/aarya/miniconda3/envs/pyTorch/lib/python3.9/site-packages/PIL/Image.py:970: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# loss=6.46245: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Test Epoch 200: Acc@1:26.36%: 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]

# %%
import pandas as pd
import matplotlib.pyplot as plt
accuracy_df = pd.read_csv('example_logs/accuracy.csv')
accuracy = accuracy_df['knn_monitor_accuracy']
plt.plot(accuracy)

plt.title('KNN Monitored Accuracy Plot')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.show()
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
loss_df = pd.read_csv('example_logs/loss_histories.csv')
loss = loss_df['loss']
plt.plot(loss)

plt.title('Loss Plot')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.show()
