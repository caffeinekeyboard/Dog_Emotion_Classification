# %% [markdown]
# #### Implementation of Momentum Contrast for Unsupervised Visual Representation Learning, to analyse and detect dog emotions.
# - Paper : https://arxiv.org/abs/1911.05722
# - Code : https://github.com/facebookresearch/moco

# %%
#Code utilities
import logging
import os 
import random
from functools import partial

#Core libraries
import torch
from PIL import ImageFilter
from torchvision import datasets, transforms
from torchvision.models import resnet 
from tqdm import tqdm 
import numpy as np

#Metric learning utilities
from pytorch_metric_learning import losses
from pytorch_metric_learning.utils import logging_presets

#Configurations
logging.getLogger().setLevel(logging.INFO)
device = torch.device("cuda")

# %% [markdown]
# ##### Augmentation functions taken straight from https://github.com/facebookresearch/moco
# - Two-Crops Transform
# - Gaussian Blur

# %%
class TwoCropsTransform:
    """Take two random crops of one image as the query and key.
       Expects a torch tensor as an arguement in __call__(x) function and returns a list of 2 torch tensors."""

    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        q = self.base_transform(x)
        k = self.base_transform(x)
        return [q, k]
    
class GaussianBlur(object):
    """Gaussian blur augmentation in SimCLR https://arxiv.org/abs/2002.05709
       Expects a PIL Image as an arguement in __call__(x) function and returns Gaussian Blur applied PIL image."""

    def __init__(self, sigma=[0.1, 2.0]):
        self.sigma = sigma

    def __call__(self, x):
        sigma = random.uniform(self.sigma[0], self.sigma[1])
        x = x.filter(ImageFilter.GaussianBlur(radius=sigma))
        return x

# %% [markdown]
# ##### Dataset creation function.
# - Reduces overhead variable accumulation.
# - Easy to steal from MoCo :-)

# %%
#Calculated MEAN and STANDARD DEVIATION values from normalization_params.ipynb
MEAN = [0.5435, 0.5091, 0.4462]
STD = [0.2979, 0.2869, 0.2920]

# %%
def create_dataset(batch_size):
    normalize = transforms.Normalize(MEAN, STD)
    
    train_transform = transforms.Compose(
        [
            transforms.RandomResizedCrop(96),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
            transforms.RandomGrayscale(p=0.2),
            transforms.ToTensor(),
            normalize,
        ]
    )

    train_transform = TwoCropsTransform(train_transform)
    val_transform = transforms.Compose([transforms.Resize((96, 96)), transforms.ToTensor(), normalize])
    
    train_dir = 'data/train/'
    val_dir = 'data/validation/'
    test_dir = 'data/test/'
    
    train_dataset = datasets.ImageFolder(
        train_dir , transform=train_transform
    )
    train_dataset_for_eval = datasets.ImageFolder(
        val_dir, transform=val_transform
    )
    val_dataset = datasets.ImageFolder(
        test_dir, transform=val_transform
    )

    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True,
        drop_last=True,
    )

    train_loader_for_eval = torch.utils.data.DataLoader(
        train_dataset_for_eval,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    return (
        train_dataset,
        train_dataset_for_eval,
        val_dataset,
        train_loader,
        train_loader_for_eval,
        val_loader,
    )

# %% [markdown]
# ##### SplitBatchNorm: simulate multi-gpu behavior of BatchNorm in one gpu by splitting alone the batch dimension.
# - Yanked from https://github.com/davidcpage/cifar10-fast/blob/master/torch_backend.py

# %%
class SplitBatchNorm(torch.nn.BatchNorm2d):
    def __init__(self, num_features, num_splits, **kw):
        super().__init__(num_features, **kw)
        self.num_splits = num_splits

    def forward(self, input):
        N, C, H, W = input.shape
        if self.training or not self.track_running_stats:
            running_mean_split = self.running_mean.repeat(self.num_splits)
            running_var_split = self.running_var.repeat(self.num_splits)
            outcome = torch.nn.functional.batch_norm(
                input.view(-1, C * self.num_splits, H, W),
                running_mean_split,
                running_var_split,
                self.weight.repeat(self.num_splits),
                self.bias.repeat(self.num_splits),
                True,
                self.momentum,
                self.eps,
            ).view(N, C, H, W)
            self.running_mean.data.copy_(
                running_mean_split.view(self.num_splits, C).mean(dim=0)
            )
            self.running_var.data.copy_(
                running_var_split.view(self.num_splits, C).mean(dim=0)
            )
            return outcome
        else:
            return torch.nn.functional.batch_norm(
                input,
                self.running_mean,
                self.running_var,
                self.weight,
                self.bias,
                False,
                self.momentum,
                self.eps,
            )

# %% [markdown]
# ##### Model definition and code for copying params from encQ to encK.

# %%
class ModelBase(torch.nn.Module):
    """
    Common CIFAR ResNet recipe.
    Comparing with ImageNet ResNet recipe, it:
    (i) replaces conv1 with kernel=3, str=1
    (ii) removes pool1
    """

    def __init__(self, feature_dim=128, arch="resnet18", bn_splits=8):
        super(ModelBase, self).__init__()

        # use split batchnorm
        norm_layer = (
            partial(SplitBatchNorm, num_splits=bn_splits)
            if bn_splits > 1
            else torch.nn.BatchNorm2d
        )
        resnet_arch = getattr(resnet, arch)
        net = resnet_arch(num_classes=feature_dim, norm_layer=norm_layer)

        self.net = []
        for name, module in net.named_children():
            if name == "conv1":
                module = torch.nn.Conv2d(
                    3, 64, kernel_size=3, stride=1, padding=1, bias=False
                )
            if isinstance(module, torch.nn.MaxPool2d):
                continue
            if isinstance(module, torch.nn.Linear):
                self.net.append(torch.nn.Flatten(1))
            self.net.append(module)

        self.net = torch.nn.Sequential(*self.net)

    def forward(self, x):
        x = self.net(x)
        # note: not normalized here
        return x


def copy_params(encQ, encK, m=None):
    if m is None:
        for param_q, param_k in zip(encQ.parameters(), encK.parameters()):
            param_k.data.copy_(param_q.data)  # initialize
            param_k.requires_grad = False  # not update by gradient
    else:
        for param_q, param_k in zip(encQ.parameters(), encK.parameters()):
            param_k.data = param_k.data * m + param_q.data * (1.0 - m)


def create_encoder():
    model = ModelBase()
    model = torch.nn.DataParallel(model)
    model.to(device)
    return model

# %% [markdown]
# ##### Evaluation Functions.

# %%
def test(net, memory_data_loader, test_data_loader, epoch, knn_k, knn_t, record_keeper):
    net.eval()
    classes = len(memory_data_loader.dataset.classes)
    total_top1, total_num, feature_bank = 0.0, 0, []
    with torch.no_grad():
        # generate feature bank
        for data, target in tqdm(memory_data_loader, desc="Feature extracting"):
            feature = net(data.cuda(non_blocking=True))
            feature = torch.nn.functional.normalize(feature, dim=1)
            feature_bank.append(feature)
        # [D, N]
        feature_bank = torch.cat(feature_bank, dim=0).t().contiguous()
        # [N]
        feature_labels = torch.tensor(
            memory_data_loader.dataset.targets, device=feature_bank.device
        )
        # loop test data to predict the label by weighted knn search
        test_bar = tqdm(test_data_loader)
        for data, target in test_bar:
            data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            feature = net(data)
            feature = torch.nn.functional.normalize(feature, dim=1)

            pred_labels = knn_predict(
                feature, feature_bank, feature_labels, classes, knn_k, knn_t
            )

            total_num += data.size(0)
            total_top1 += (pred_labels[:, 0] == target).float().sum().item()
            acc = total_top1 / total_num * 100
            test_bar.set_description("Test Epoch {}: Acc@1:{:.2f}%".format(epoch, acc))

    record_keeper.update_records(
        {"knn_monitor_accuracy": acc},
        epoch,
        parent_name="accuracy",
    )
    record_keeper.save_records()
    return acc


def knn_predict(feature, feature_bank, feature_labels, classes, knn_k, knn_t):
    # compute cos similarity between each feature vector and feature bank ---> [B, N]
    sim_matrix = torch.mm(feature, feature_bank)
    # [B, K]
    sim_weight, sim_indices = sim_matrix.topk(k=knn_k, dim=-1)
    # [B, K]
    sim_labels = torch.gather(
        feature_labels.expand(feature.size(0), -1), dim=-1, index=sim_indices
    )
    sim_weight = (sim_weight / knn_t).exp()

    # counts for each class
    one_hot_label = torch.zeros(
        feature.size(0) * knn_k, classes, device=sim_labels.device
    )
    # [B*K, C]
    one_hot_label = one_hot_label.scatter(
        dim=-1, index=sim_labels.view(-1, 1), value=1.0
    )
    # weighted score ---> [B, C]
    pred_scores = torch.sum(
        one_hot_label.view(feature.size(0), -1, classes) * sim_weight.unsqueeze(dim=-1),
        dim=1,
    )

    pred_labels = pred_scores.argsort(dim=-1, descending=True)
    return pred_labels

# %% [markdown]
# ##### Training and logging functions.

# %%
def update_records(loss, loss_fn, optimizer, record_keeper, global_iteration):
    def optimizer_custom_attr_func(opt):
        return {"lr": opt.param_groups[0]["lr"]}

    record_these = [
        [{"loss": loss.item()}, {"parent_name": "loss_histories"}],
        [{"loss_function": loss_fn}, {"recursive_types": [torch.nn.Module]}],
        [{"optimizer": optimizer}, {"custom_attr_func": optimizer_custom_attr_func}],
    ]
    for record, kwargs in record_these:
        record_keeper.update_records(record, global_iteration, **kwargs)


def save_model(encQ):
    model_folder = "example_saved_models"
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)
    torch.save(encQ.state_dict(), "{}/encQ_best.pth".format(model_folder))



def batch_shuffle_single_gpu(x):
    """
    Batch shuffle, for making use of BatchNorm.
    """
    # random shuffle index
    idx_shuffle = torch.randperm(x.shape[0]).cuda()

    # index for restoring
    idx_unshuffle = torch.argsort(idx_shuffle)

    return x[idx_shuffle], idx_unshuffle



def batch_unshuffle_single_gpu(x, idx_unshuffle):
    """
    Undo batch shuffle.
    """
    return x[idx_unshuffle]


def create_labels(num_pos_pairs, previous_max_label):
    # create labels that indicate what the positive pairs are
    labels = torch.arange(0, num_pos_pairs)
    labels = torch.cat((labels, labels)).to(device)
    # add an offset so that the labels do not overlap with any labels in the memory queue
    labels += previous_max_label + 1
    # we want to enqueue the output of encK, which is the 2nd half of the batch
    enqueue_mask = torch.zeros(len(labels)).bool()
    enqueue_mask[num_pos_pairs:] = True
    return labels, enqueue_mask


def train(
    encQ,
    encK,
    paramK_momentum,
    loss_fn,
    optimizer,
    train_loader,
    record_keeper,
    global_iteration,
):
    encQ.train()
    pbar = tqdm(train_loader)
    for images, _ in pbar:
        previous_max_label = torch.max(loss_fn.label_memory)
        imgQ = images[0].to(device)
        imgK = images[1].to(device)

        # compute output
        encQ_out = encQ(imgQ)
        with torch.no_grad():  # no gradient to keys
            copy_params(encQ, encK, m=paramK_momentum)
            imgK, idx_unshuffle = batch_shuffle_single_gpu(imgK)
            encK_out = encK(imgK)
            encK_out = batch_unshuffle_single_gpu(encK_out, idx_unshuffle)

        all_enc = torch.cat([encQ_out, encK_out], dim=0)
        labels, enqueue_mask = create_labels(encQ_out.size(0), previous_max_label)
        loss = loss_fn(all_enc, labels, enqueue_mask=enqueue_mask)

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pbar.set_description("loss=%.5f" % loss.item())
        update_records(
            loss, loss_fn, optimizer, record_keeper, global_iteration["iter"]
        )
        global_iteration["iter"] += 1

# %% [markdown]
# ##### Start Tensorboard and delete old folders.

# %%
# !rm -rfv example_logs example_tensorboard example_saved_models
# %load_ext tensorboard
# %tensorboard --logdir example_tensorboard
# Out:
# removed 'example_logs/loss_function_CrossBatchMemory.csv'
# removed 'example_logs/logs.db'
# removed 'example_logs/optimizer_SGD.csv'
# removed 'example_logs/loss_histories.csv'
# removed 'example_logs/accuracy.csv'
# removed directory 'example_logs'
# removed 'example_tensorboard/events.out.tfevents.1712823139.aarya-ExcaliburOMEN.32633.0'
# removed directory 'example_tensorboard'
# removed 'example_saved_models/encQ_best.pth'
# removed directory 'example_saved_models'
#       <iframe id="tensorboard-frame-b21ffdbc132bdfb8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b21ffdbc132bdfb8");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
batch_size = 128
lr = 0.03
paramK_momentum = 0.99
memory_size = 2048
num_epochs = 1800
knn_k = 200
knn_t = 0.1

(
    train_dataset,
    train_dataset_for_eval,
    val_dataset,
    train_loader,
    train_loader_for_eval,
    val_loader,
) = create_dataset(batch_size)

encQ = create_encoder()
encK = create_encoder()

# copy params from encQ into encK
copy_params(encQ, encK)

optimizer = torch.optim.SGD(encQ.parameters(), lr, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_epochs)

###########################################################
### Set the loss function and the (optional) miner here ###
###########################################################
loss_fn = losses.CrossBatchMemory(
    loss=losses.NTXentLoss(temperature=0.1), embedding_size=128, memory_size=memory_size
)

dataset_dict = {"train": train_dataset_for_eval, "val": val_dataset}
record_keeper, _, _ = logging_presets.get_record_keeper(
    "example_logs", "example_tensorboard"
)
hooks = logging_presets.get_hook_container(record_keeper)

# first check untrained performance
epoch = 0
best_accuracy = test(
    encQ, train_loader_for_eval, val_loader, epoch, knn_k, knn_t, record_keeper
)

global_iteration = {"iter": 0}
for epoch in range(1, num_epochs + 1):
    logging.info("Starting epoch {}".format(epoch))
    train(
        encQ,
        encK,
        paramK_momentum,
        loss_fn,
        optimizer,
        train_loader,
        record_keeper,
        global_iteration,
    )
    curr_accuracy = test(
        encQ, train_loader_for_eval, val_loader, epoch, knn_k, knn_t, record_keeper
    )
    if curr_accuracy > best_accuracy:
        best_accuracy = curr_accuracy
        save_model(encQ)
    scheduler.step()
# Out:
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.54it/s]
# Test Epoch 0: Acc@1:15.14%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 1
# loss=6.91086: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.64it/s]
# Test Epoch 1: Acc@1:21.14%: 100%|██████████| 3/3 [00:01<00:00,  1.90it/s]
# INFO:root:Starting epoch 2
# loss=6.66268: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 2: Acc@1:19.43%: 100%|██████████| 3/3 [00:01<00:00,  1.90it/s]
# INFO:root:Starting epoch 3
# loss=6.21079: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.65it/s]
# Test Epoch 3: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.90it/s]
# INFO:root:Starting epoch 4
# loss=5.84049: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.65it/s]
# Test Epoch 4: Acc@1:17.43%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 5
# loss=5.73042: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.65it/s]
# Test Epoch 5: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.90it/s]
# INFO:root:Starting epoch 6
# loss=5.57305: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.64it/s]
# Test Epoch 6: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 7
# loss=5.65440: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.64it/s]
# Test Epoch 7: Acc@1:20.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 8
# loss=5.69751: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 8: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 9
# loss=5.66174: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.64it/s]
# Test Epoch 9: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 10
# loss=5.66892: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 10: Acc@1:19.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 11
# loss=5.83630: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 11: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 12
# loss=5.71853: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 12: Acc@1:21.14%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 13
# loss=5.76127: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 13: Acc@1:21.71%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 14
# loss=5.81858: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 14: Acc@1:20.57%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 15
# loss=5.86873: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 15: Acc@1:21.14%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 16
# loss=5.83694: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.64it/s]
# Test Epoch 16: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 17
# loss=5.93295: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 17: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 18
# loss=5.88737: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 18: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 19
# loss=5.87574: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 19: Acc@1:21.14%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 20
# loss=5.98794: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.47it/s]
# Test Epoch 20: Acc@1:21.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 21
# loss=5.99757: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 21: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 22
# loss=6.10065: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 22: Acc@1:21.71%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 23
# loss=6.06653: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 23: Acc@1:16.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 24
# loss=6.17297: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.45it/s]
# Test Epoch 24: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.62it/s]
# INFO:root:Starting epoch 25
# loss=6.16544: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.86it/s]
# Test Epoch 25: Acc@1:20.57%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 26
# loss=6.23199: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 26: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 27
# loss=6.14380: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 27: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 28
# loss=6.14018: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 28: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 29
# loss=6.08924: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 29: Acc@1:22.29%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 30
# loss=6.07958: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 30: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 31
# loss=6.13800: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 31: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.72it/s]
# INFO:root:Starting epoch 32
# loss=6.08999: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.41it/s]
# Test Epoch 32: Acc@1:20.29%: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# INFO:root:Starting epoch 33
# loss=6.26229: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 33: Acc@1:20.00%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 34
# loss=6.24002: 100%|██████████| 11/11 [00:07<00:00,  1.41it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 34: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 35
# loss=6.31550: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 35: Acc@1:21.14%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 36
# loss=6.18773: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 36: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 37
# loss=6.12432: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 37: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 38
# loss=6.21501: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 38: Acc@1:22.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 39
# loss=6.29180: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 39: Acc@1:22.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 40
# loss=6.24615: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 40: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 41
# loss=6.19135: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 41: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 42
# loss=6.21622: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 42: Acc@1:22.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 43
# loss=6.12935: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 43: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 44
# loss=6.22268: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 44: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 45
# loss=6.13303: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 45: Acc@1:22.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 46
# loss=6.18982: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 46: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 47
# loss=6.28597: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 47: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 48
# loss=5.99127: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 48: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.89it/s]
# INFO:root:Starting epoch 49
# loss=6.16457: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 49: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 50
# loss=6.08915: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 50: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 51
# loss=6.10944: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 51: Acc@1:18.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 52
# loss=6.01080: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 52: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 53
# loss=6.13806: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 53: Acc@1:22.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 54
# loss=6.04188: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 54: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 55
# loss=6.13321: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 55: Acc@1:22.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 56
# loss=6.11365: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 56: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 57
# loss=6.03789: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 57: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 58
# loss=6.15925: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 58: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 59
# loss=6.03145: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 59: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 60
# loss=6.00820: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 60: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 61
# loss=5.94686: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 61: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 62
# loss=5.85690: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 62: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 63
# loss=6.01840: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 63: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 64
# loss=6.15091: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 64: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 65
# loss=6.03034: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 65: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 66
# loss=5.99349: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 66: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 67
# loss=5.94495: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 67: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 68
# loss=5.97977: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 68: Acc@1:22.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 69
# loss=6.00185: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 69: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 70
# loss=6.05515: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 70: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 71
# loss=6.06089: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 71: Acc@1:21.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 72
# loss=5.80673: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 72: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 73
# loss=5.95915: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 73: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 74
# loss=5.99910: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 74: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 75
# loss=6.19262: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 75: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 76
# loss=6.08501: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 76: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 77
# loss=6.11474: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 77: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 78
# loss=5.96231: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 78: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 79
# loss=5.77439: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 79: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 80
# loss=5.92044: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 80: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 81
# loss=5.90588: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 81: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 82
# loss=5.56928: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 82: Acc@1:28.57%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 83
# loss=5.72565: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 83: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 84
# loss=5.89673: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 84: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 85
# loss=6.16668: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 85: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 86
# loss=5.87275: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 86: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 87
# loss=5.72949: 100%|██████████| 11/11 [00:07<00:00,  1.41it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 87: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 88
# loss=5.81613: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 88: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 89
# loss=5.83133: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 89: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 90
# loss=5.87482: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 90: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 91
# loss=6.10521: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 91: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 92
# loss=5.86478: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 92: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 93
# loss=5.53113: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 93: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
# INFO:root:Starting epoch 94
# loss=5.60960: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.39it/s]
# Test Epoch 94: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.70it/s]
# INFO:root:Starting epoch 95
# loss=5.91500: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.43it/s]
# Test Epoch 95: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# INFO:root:Starting epoch 96
# loss=5.67964: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.46it/s]
# Test Epoch 96: Acc@1:28.00%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 97
# loss=5.88270: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 97: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 98
# loss=5.75468: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 98: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 99
# loss=5.78933: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 99: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 100
# loss=5.80840: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 100: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 101
# loss=5.77038: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 101: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 102
# loss=5.67331: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 102: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 103
# loss=5.82562: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 103: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 104
# loss=5.74239: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 104: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 105
# loss=5.80913: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 105: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 106
# loss=5.64675: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 106: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 107
# loss=5.91246: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.48it/s]
# Test Epoch 107: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 108
# loss=5.91229: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 108: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 109
# loss=5.53043: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 109: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 110
# loss=5.78975: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 110: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 111
# loss=5.45034: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 111: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 112
# loss=5.75609: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 112: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 113
# loss=5.45374: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 113: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 114
# loss=5.49735: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.38it/s]
# Test Epoch 114: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
# INFO:root:Starting epoch 115
# loss=5.49920: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 115: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 116
# loss=5.50936: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.48it/s]
# Test Epoch 116: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 117
# loss=5.81486: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 117: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 118
# loss=5.50054: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 118: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 119
# loss=5.54239: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.36it/s]
# Test Epoch 119: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.74it/s]
# INFO:root:Starting epoch 120
# loss=5.50652: 100%|██████████| 11/11 [00:08<00:00,  1.27it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.48it/s]
# Test Epoch 120: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 121
# loss=5.52238: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 121: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 122
# loss=5.45864: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.48it/s]
# Test Epoch 122: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 123
# loss=5.47535: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.51it/s]
# Test Epoch 123: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 124
# loss=5.64593: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.45it/s]
# Test Epoch 124: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.73it/s]
# INFO:root:Starting epoch 125
# loss=5.58121: 100%|██████████| 11/11 [00:08<00:00,  1.25it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 125: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 126
# loss=5.55522: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 126: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 127
# loss=5.59423: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 127: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 128
# loss=5.63089: 100%|██████████| 11/11 [00:09<00:00,  1.17it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 128: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 129
# loss=5.55874: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 129: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 130
# loss=5.49858: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 130: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 131
# loss=5.37536: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 131: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 132
# loss=5.60042: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 132: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 133
# loss=5.51814: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 133: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 134
# loss=5.37069: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.51it/s]
# Test Epoch 134: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 135
# loss=5.51755: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.44it/s]
# Test Epoch 135: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.69it/s]
# INFO:root:Starting epoch 136
# loss=5.36609: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 136: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 137
# loss=5.35692: 100%|██████████| 11/11 [00:09<00:00,  1.13it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.39it/s]
# Test Epoch 137: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.69it/s]
# INFO:root:Starting epoch 138
# loss=5.72987: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.40it/s]
# Test Epoch 138: Acc@1:22.86%: 100%|██████████| 3/3 [00:01<00:00,  1.76it/s]
# INFO:root:Starting epoch 139
# loss=5.52911: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.57it/s]
# Test Epoch 139: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# INFO:root:Starting epoch 140
# loss=5.38361: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.39it/s]
# Test Epoch 140: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
# INFO:root:Starting epoch 141
# loss=5.26989: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.32it/s]
# Test Epoch 141: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.74it/s]
# INFO:root:Starting epoch 142
# loss=5.21963: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.44it/s]
# Test Epoch 142: Acc@1:29.14%: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# INFO:root:Starting epoch 143
# loss=5.48754: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.44it/s]
# Test Epoch 143: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 144
# loss=5.47423: 100%|██████████| 11/11 [00:08<00:00,  1.27it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.64it/s]
# Test Epoch 144: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# INFO:root:Starting epoch 145
# loss=5.48272: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 145: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 146
# loss=5.03859: 100%|██████████| 11/11 [00:08<00:00,  1.28it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.51it/s]
# Test Epoch 146: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 147
# loss=5.45160: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 147: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 148
# loss=5.43096: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.45it/s]
# Test Epoch 148: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 149
# loss=5.50396: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.48it/s]
# Test Epoch 149: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 150
# loss=5.58338: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 150: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# INFO:root:Starting epoch 151
# loss=5.29496: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 151: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 152
# loss=5.23752: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 152: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 153
# loss=5.20615: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 153: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 154
# loss=5.19500: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.46it/s]
# Test Epoch 154: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.74it/s]
# INFO:root:Starting epoch 155
# loss=5.08473: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 155: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 156
# loss=5.44671: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.41it/s]
# Test Epoch 156: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
# INFO:root:Starting epoch 157
# loss=5.30303: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 157: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# INFO:root:Starting epoch 158
# loss=5.13920: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 158: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.76it/s]
# INFO:root:Starting epoch 159
# loss=5.36511: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.47it/s]
# Test Epoch 159: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# INFO:root:Starting epoch 160
# loss=5.16930: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 160: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# INFO:root:Starting epoch 161
# loss=5.22926: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 161: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 162
# loss=5.28683: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 162: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 163
# loss=5.39271: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 163: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 164
# loss=5.16440: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 164: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 165
# loss=5.28877: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 165: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 166
# loss=5.08928: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 166: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 167
# loss=5.44492: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 167: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 168
# loss=5.20400: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 168: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 169
# loss=5.29713: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 169: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 170
# loss=5.11814: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 170: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 171
# loss=5.17059: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 171: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 172
# loss=5.07183: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 172: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 173
# loss=5.32815: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 173: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 174
# loss=4.90488: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 174: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 175
# loss=4.87795: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 175: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 176
# loss=5.32109: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.46it/s]
# Test Epoch 176: Acc@1:29.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 177
# loss=4.99966: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 177: Acc@1:30.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 178
# loss=5.10581: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 178: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 179
# loss=5.06063: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 179: Acc@1:28.57%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 180
# loss=5.08707: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 180: Acc@1:29.43%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 181
# loss=5.10308: 100%|██████████| 11/11 [00:09<00:00,  1.19it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 181: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 182
# loss=5.09679: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 182: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 183
# loss=5.19172: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 183: Acc@1:29.14%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 184
# loss=5.11253: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 184: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 185
# loss=5.13598: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.71it/s]
# Test Epoch 185: Acc@1:30.00%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 186
# loss=5.03053: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 186: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 187
# loss=4.90421: 100%|██████████| 11/11 [00:08<00:00,  1.26it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 187: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 188
# loss=5.18980: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 188: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 189
# loss=4.85218: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 189: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 190
# loss=4.92301: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 190: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 191
# loss=5.05760: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 191: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 192
# loss=4.82717: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 192: Acc@1:29.43%: 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# INFO:root:Starting epoch 193
# loss=5.04756: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 193: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 194
# loss=4.93007: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 194: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 195
# loss=5.29088: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 195: Acc@1:28.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 196
# loss=4.89341: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 196: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 197
# loss=4.96745: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 197: Acc@1:29.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 198
# loss=5.09791: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 198: Acc@1:28.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 199
# loss=5.04808: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 199: Acc@1:31.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 200
# loss=4.89956: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 200: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 201
# loss=4.66541: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 201: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 202
# loss=4.63552: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 202: Acc@1:29.71%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 203
# loss=4.73576: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 203: Acc@1:29.14%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 204
# loss=4.88597: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 204: Acc@1:29.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 205
# loss=4.97441: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 205: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 206
# loss=4.71236: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 206: Acc@1:29.71%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 207
# ...
# INFO:root:Starting epoch 1733
# loss=1.26831: 100%|██████████| 11/11 [00:09<00:00,  1.12it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1733: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 1734
# loss=1.22362: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.68it/s]
# Test Epoch 1734: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1735
# loss=1.25410: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 1735: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1736
# loss=1.32490: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1736: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 1737
# loss=1.25698: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1737: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 1738
# loss=1.31957: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 1738: Acc@1:36.29%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1739
# loss=1.29840: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 1739: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1740
# loss=1.23693: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1740: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1741
# loss=1.25761: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.51it/s]
# Test Epoch 1741: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1742
# loss=1.23688: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 1742: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1743
# loss=1.34431: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 1743: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1744
# loss=1.22384: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.70it/s]
# Test Epoch 1744: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 1745
# loss=1.25503: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 1745: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
# INFO:root:Starting epoch 1746
# loss=1.12444: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1746: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1747
# loss=1.23041: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 1747: Acc@1:36.57%: 100%|██████████| 3/3 [00:02<00:00,  1.24it/s]
# INFO:root:Starting epoch 1748
# loss=1.37074: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1748: Acc@1:36.57%: 100%|██████████| 3/3 [00:02<00:00,  1.23it/s]
# INFO:root:Starting epoch 1749
# loss=1.17216: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.51it/s]
# Test Epoch 1749: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1750
# loss=1.40768: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 1750: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1751
# loss=1.37085: 100%|██████████| 11/11 [00:08<00:00,  1.28it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 1751: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# INFO:root:Starting epoch 1752
# loss=1.23619: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.37it/s]
# Test Epoch 1752: Acc@1:36.29%: 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# INFO:root:Starting epoch 1753
# loss=1.20128: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.44it/s]
# Test Epoch 1753: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
# INFO:root:Starting epoch 1754
# loss=1.18394: 100%|██████████| 11/11 [00:08<00:00,  1.27it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.47it/s]
# Test Epoch 1754: Acc@1:36.86%: 100%|██████████| 3/3 [00:02<00:00,  1.22it/s]
# INFO:root:Starting epoch 1755
# loss=1.18418: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 1755: Acc@1:36.86%: 100%|██████████| 3/3 [00:02<00:00,  1.24it/s]
# INFO:root:Starting epoch 1756
# loss=1.29550: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.45it/s]
# Test Epoch 1756: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.70it/s]
# INFO:root:Starting epoch 1757
# loss=1.13097: 100%|██████████| 11/11 [00:08<00:00,  1.26it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.48it/s]
# Test Epoch 1757: Acc@1:36.29%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 1758
# loss=1.14054: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.00it/s]
# Test Epoch 1758: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.72it/s]
# INFO:root:Starting epoch 1759
# loss=1.20106: 100%|██████████| 11/11 [00:08<00:00,  1.25it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.38it/s]
# Test Epoch 1759: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1760
# loss=1.46954: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.44it/s]
# Test Epoch 1760: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 1761
# loss=1.21051: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 1761: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 1762
# loss=1.27173: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.45it/s]
# Test Epoch 1762: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1763
# loss=1.19152: 100%|██████████| 11/11 [00:08<00:00,  1.27it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 1763: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1764
# loss=1.22202: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 1764: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1765
# loss=1.21155: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.50it/s]
# Test Epoch 1765: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1766
# loss=1.30955: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.51it/s]
# Test Epoch 1766: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.77it/s]
# INFO:root:Starting epoch 1767
# loss=1.23874: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.51it/s]
# Test Epoch 1767: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 1768
# loss=1.17923: 100%|██████████| 11/11 [00:08<00:00,  1.23it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.70it/s]
# Test Epoch 1768: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1769
# loss=1.20195: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.69it/s]
# Test Epoch 1769: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1770
# loss=1.26249: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.51it/s]
# Test Epoch 1770: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 1771
# loss=1.21594: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 1771: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1772
# loss=1.18325: 100%|██████████| 11/11 [00:09<00:00,  1.22it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1772: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1773
# loss=1.27795: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.67it/s]
# Test Epoch 1773: Acc@1:37.14%: 100%|██████████| 3/3 [00:02<00:00,  1.24it/s]
# INFO:root:Starting epoch 1774
# loss=1.22572: 100%|██████████| 11/11 [00:08<00:00,  1.27it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.49it/s]
# Test Epoch 1774: Acc@1:37.14%: 100%|██████████| 3/3 [00:02<00:00,  1.23it/s]
# INFO:root:Starting epoch 1775
# loss=1.25805: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.37it/s]
# Test Epoch 1775: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.73it/s]
# INFO:root:Starting epoch 1776
# loss=1.25967: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.65it/s]
# Test Epoch 1776: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.76it/s]
# INFO:root:Starting epoch 1777
# loss=1.31691: 100%|██████████| 11/11 [00:09<00:00,  1.12it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 1777: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1778
# loss=1.25641: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1778: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1779
# loss=1.32554: 100%|██████████| 11/11 [00:08<00:00,  1.25it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.46it/s]
# Test Epoch 1779: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.75it/s]
# INFO:root:Starting epoch 1780
# loss=1.25109: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 1780: Acc@1:37.43%: 100%|██████████| 3/3 [00:02<00:00,  1.24it/s]
# INFO:root:Starting epoch 1781
# loss=1.38346: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 1781: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 1782
# loss=1.16503: 100%|██████████| 11/11 [00:08<00:00,  1.25it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.41it/s]
# Test Epoch 1782: Acc@1:36.57%: 100%|██████████| 3/3 [00:02<00:00,  1.19it/s]
# INFO:root:Starting epoch 1783
# loss=1.34535: 100%|██████████| 11/11 [00:09<00:00,  1.17it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.35it/s]
# Test Epoch 1783: Acc@1:37.14%: 100%|██████████| 3/3 [00:02<00:00,  1.22it/s]
# INFO:root:Starting epoch 1784
# loss=1.20250: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1784: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# INFO:root:Starting epoch 1785
# loss=1.26233: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1785: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.68it/s]
# INFO:root:Starting epoch 1786
# loss=1.11637: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 1786: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1787
# loss=1.33835: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.37it/s]
# Test Epoch 1787: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 1788
# loss=1.19373: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.37it/s]
# Test Epoch 1788: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.70it/s]
# INFO:root:Starting epoch 1789
# loss=1.23921: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.38it/s]
# Test Epoch 1789: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.66it/s]
# INFO:root:Starting epoch 1790
# loss=1.23567: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.37it/s]
# Test Epoch 1790: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1791
# loss=1.23734: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1791: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1792
# loss=1.26345: 100%|██████████| 11/11 [00:09<00:00,  1.11it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1792: Acc@1:37.71%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 1793
# loss=1.26704: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 1793: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1794
# loss=1.42226: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 1794: Acc@1:36.29%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1795
# loss=1.15926: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1795: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1796
# loss=1.24574: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1796: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1797
# loss=1.28869: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1797: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1798
# loss=1.09195: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1798: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1799
# loss=1.27152: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1799: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1800
# loss=1.33147: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1800: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
accuracy_df = pd.read_csv('example_logs/accuracy.csv')
accuracy = accuracy_df['knn_monitor_accuracy']
plt.plot(accuracy)

plt.title('KNN Monitored Accuracy Plot')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.show()
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
accuracy.max()
# Out:
# 42.0

# %%
loss_df = pd.read_csv('example_logs/loss_histories.csv')
loss = loss_df['loss']
plt.plot(loss)

plt.title('Loss Plot')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.show()
