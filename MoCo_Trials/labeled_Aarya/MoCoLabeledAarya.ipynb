# %% [markdown]
# #### Implementation of Momentum Contrast for Unsupervised Visual Representation Learning, to analyse and detect dog emotions.
# - Paper : https://arxiv.org/abs/1911.05722
# - Code : https://github.com/facebookresearch/moco

# %%
import logging
import os 
import random
from functools import partial

import torch
from PIL import ImageFilter
from torchvision import datasets, transforms
from torchvision.models import resnet 
from tqdm import tqdm 
import numpy as np

from pytorch_metric_learning import losses
from pytorch_metric_learning.utils import logging_presets

logging.getLogger().setLevel(logging.INFO)

device = torch.device("cuda")

# %% [markdown]
# ##### Augmentation functions taken straight from https://github.com/facebookresearch/moco
# - Two-Crops Transform
# - Gaussian Blur

# %%
class TwoCropsTransform:
    """Take two random crops of one image as the query and key."""

    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        q = self.base_transform(x)
        k = self.base_transform(x)
        return [q, k]
    
class GaussianBlur(object):
    """Gaussian blur augmentation in SimCLR https://arxiv.org/abs/2002.05709"""

    def __init__(self, sigma=[0.1, 2.0]):
        self.sigma = sigma

    def __call__(self, x):
        sigma = random.uniform(self.sigma[0], self.sigma[1])
        x = x.filter(ImageFilter.GaussianBlur(radius=sigma))
        return x

# %% [markdown]
# ##### Dataset creation function.
# - Reduces overhead variable accumulation.
# - Easy to steal from MoCo :-)

# %%
MEAN = [0.47365573, 0.4402452, 0.38663769]
STD = [0.26914782, 0.26083042, 0.2624779]

# %%
def create_dataset(batch_size):
    normalize = transforms.Normalize(MEAN, STD)
    
    train_transform = transforms.Compose(
        [
            transforms.RandomResizedCrop(96),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
            transforms.RandomGrayscale(p=0.2),
            transforms.ToTensor(),
            normalize,
        ]
    )

    train_transform = TwoCropsTransform(train_transform)
    val_transform = transforms.Compose([transforms.Resize((96, 96)), transforms.ToTensor(), normalize])
    
    train_dir = 'data/train/'
    val_dir = 'data/validation/'
    test_dir = 'data/test/'
    
    train_dataset = datasets.ImageFolder(
        train_dir , transform=train_transform
    )
    train_dataset_for_eval = datasets.ImageFolder(
        val_dir, transform=val_transform
    )
    val_dataset = datasets.ImageFolder(
        test_dir, transform=val_transform
    )

    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True,
        drop_last=True,
    )

    train_loader_for_eval = torch.utils.data.DataLoader(
        train_dataset_for_eval,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    return (
        train_dataset,
        train_dataset_for_eval,
        val_dataset,
        train_loader,
        train_loader_for_eval,
        val_loader,
    )

# %% [markdown]
# ##### SplitBatchNorm: simulate multi-gpu behavior of BatchNorm in one gpu by splitting alone the batch dimension.
# - Yanked from https://github.com/davidcpage/cifar10-fast/blob/master/torch_backend.py

# %%
class SplitBatchNorm(torch.nn.BatchNorm2d):
    def __init__(self, num_features, num_splits, **kw):
        super().__init__(num_features, **kw)
        self.num_splits = num_splits

    def forward(self, input):
        N, C, H, W = input.shape
        if self.training or not self.track_running_stats:
            running_mean_split = self.running_mean.repeat(self.num_splits)
            running_var_split = self.running_var.repeat(self.num_splits)
            outcome = torch.nn.functional.batch_norm(
                input.view(-1, C * self.num_splits, H, W),
                running_mean_split,
                running_var_split,
                self.weight.repeat(self.num_splits),
                self.bias.repeat(self.num_splits),
                True,
                self.momentum,
                self.eps,
            ).view(N, C, H, W)
            self.running_mean.data.copy_(
                running_mean_split.view(self.num_splits, C).mean(dim=0)
            )
            self.running_var.data.copy_(
                running_var_split.view(self.num_splits, C).mean(dim=0)
            )
            return outcome
        else:
            return torch.nn.functional.batch_norm(
                input,
                self.running_mean,
                self.running_var,
                self.weight,
                self.bias,
                False,
                self.momentum,
                self.eps,
            )

# %% [markdown]
# ##### Model definition and code for copying params from encQ to encK.

# %%
class ModelBase(torch.nn.Module):
    """
    Common CIFAR ResNet recipe.
    Comparing with ImageNet ResNet recipe, it:
    (i) replaces conv1 with kernel=3, str=1
    (ii) removes pool1
    """

    def __init__(self, feature_dim=128, arch="resnet18", bn_splits=8):
        super(ModelBase, self).__init__()

        # use split batchnorm
        norm_layer = (
            partial(SplitBatchNorm, num_splits=bn_splits)
            if bn_splits > 1
            else torch.nn.BatchNorm2d
        )
        resnet_arch = getattr(resnet, arch)
        net = resnet_arch(num_classes=feature_dim, norm_layer=norm_layer)

        self.net = []
        for name, module in net.named_children():
            if name == "conv1":
                module = torch.nn.Conv2d(
                    3, 64, kernel_size=3, stride=1, padding=1, bias=False
                )
            if isinstance(module, torch.nn.MaxPool2d):
                continue
            if isinstance(module, torch.nn.Linear):
                self.net.append(torch.nn.Flatten(1))
            self.net.append(module)

        self.net = torch.nn.Sequential(*self.net)

    def forward(self, x):
        x = self.net(x)
        # note: not normalized here
        return x


def copy_params(encQ, encK, m=None):
    if m is None:
        for param_q, param_k in zip(encQ.parameters(), encK.parameters()):
            param_k.data.copy_(param_q.data)  # initialize
            param_k.requires_grad = False  # not update by gradient
    else:
        for param_q, param_k in zip(encQ.parameters(), encK.parameters()):
            param_k.data = param_k.data * m + param_q.data * (1.0 - m)


def create_encoder():
    model = ModelBase()
    model = torch.nn.DataParallel(model)
    model.to(device)
    return model

# %% [markdown]
# ##### Evaluation Functions.

# %%
def test(net, memory_data_loader, test_data_loader, epoch, knn_k, knn_t, record_keeper):
    net.eval()
    classes = len(memory_data_loader.dataset.classes)
    total_top1, total_num, feature_bank = 0.0, 0, []
    with torch.no_grad():
        # generate feature bank
        for data, target in tqdm(memory_data_loader, desc="Feature extracting"):
            feature = net(data.cuda(non_blocking=True))
            feature = torch.nn.functional.normalize(feature, dim=1)
            feature_bank.append(feature)
        # [D, N]
        feature_bank = torch.cat(feature_bank, dim=0).t().contiguous()
        # [N]
        feature_labels = torch.tensor(
            memory_data_loader.dataset.targets, device=feature_bank.device
        )
        # loop test data to predict the label by weighted knn search
        test_bar = tqdm(test_data_loader)
        for data, target in test_bar:
            data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            feature = net(data)
            feature = torch.nn.functional.normalize(feature, dim=1)

            pred_labels = knn_predict(
                feature, feature_bank, feature_labels, classes, knn_k, knn_t
            )

            total_num += data.size(0)
            total_top1 += (pred_labels[:, 0] == target).float().sum().item()
            acc = total_top1 / total_num * 100
            test_bar.set_description("Test Epoch {}: Acc@1:{:.2f}%".format(epoch, acc))

    record_keeper.update_records(
        {"knn_monitor_accuracy": acc},
        epoch,
        parent_name="accuracy",
    )
    record_keeper.save_records()
    return acc


def knn_predict(feature, feature_bank, feature_labels, classes, knn_k, knn_t):
    # compute cos similarity between each feature vector and feature bank ---> [B, N]
    sim_matrix = torch.mm(feature, feature_bank)
    # [B, K]
    sim_weight, sim_indices = sim_matrix.topk(k=knn_k, dim=-1)
    # [B, K]
    sim_labels = torch.gather(
        feature_labels.expand(feature.size(0), -1), dim=-1, index=sim_indices
    )
    sim_weight = (sim_weight / knn_t).exp()

    # counts for each class
    one_hot_label = torch.zeros(
        feature.size(0) * knn_k, classes, device=sim_labels.device
    )
    # [B*K, C]
    one_hot_label = one_hot_label.scatter(
        dim=-1, index=sim_labels.view(-1, 1), value=1.0
    )
    # weighted score ---> [B, C]
    pred_scores = torch.sum(
        one_hot_label.view(feature.size(0), -1, classes) * sim_weight.unsqueeze(dim=-1),
        dim=1,
    )

    pred_labels = pred_scores.argsort(dim=-1, descending=True)
    return pred_labels

# %% [markdown]
# ##### Training and logging functions.

# %%
def update_records(loss, loss_fn, optimizer, record_keeper, global_iteration):
    def optimizer_custom_attr_func(opt):
        return {"lr": opt.param_groups[0]["lr"]}

    record_these = [
        [{"loss": loss.item()}, {"parent_name": "loss_histories"}],
        [{"loss_function": loss_fn}, {"recursive_types": [torch.nn.Module]}],
        [{"optimizer": optimizer}, {"custom_attr_func": optimizer_custom_attr_func}],
    ]
    for record, kwargs in record_these:
        record_keeper.update_records(record, global_iteration, **kwargs)


def save_model(encQ):
    model_folder = "example_saved_models"
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)
    torch.save(encQ.state_dict(), "{}/encQ_best.pth".format(model_folder))



def batch_shuffle_single_gpu(x):
    """
    Batch shuffle, for making use of BatchNorm.
    """
    # random shuffle index
    idx_shuffle = torch.randperm(x.shape[0]).cuda()

    # index for restoring
    idx_unshuffle = torch.argsort(idx_shuffle)

    return x[idx_shuffle], idx_unshuffle



def batch_unshuffle_single_gpu(x, idx_unshuffle):
    """
    Undo batch shuffle.
    """
    return x[idx_unshuffle]


def create_labels(num_pos_pairs, previous_max_label):
    # create labels that indicate what the positive pairs are
    labels = torch.arange(0, num_pos_pairs)
    labels = torch.cat((labels, labels)).to(device)
    # add an offset so that the labels do not overlap with any labels in the memory queue
    labels += previous_max_label + 1
    # we want to enqueue the output of encK, which is the 2nd half of the batch
    enqueue_mask = torch.zeros(len(labels)).bool()
    enqueue_mask[num_pos_pairs:] = True
    return labels, enqueue_mask


def train(
    encQ,
    encK,
    paramK_momentum,
    loss_fn,
    optimizer,
    train_loader,
    record_keeper,
    global_iteration,
):
    encQ.train()
    pbar = tqdm(train_loader)
    for images, _ in pbar:
        previous_max_label = torch.max(loss_fn.label_memory)
        imgQ = images[0].to(device)
        imgK = images[1].to(device)

        # compute output
        encQ_out = encQ(imgQ)
        with torch.no_grad():  # no gradient to keys
            copy_params(encQ, encK, m=paramK_momentum)
            imgK, idx_unshuffle = batch_shuffle_single_gpu(imgK)
            encK_out = encK(imgK)
            encK_out = batch_unshuffle_single_gpu(encK_out, idx_unshuffle)

        all_enc = torch.cat([encQ_out, encK_out], dim=0)
        labels, enqueue_mask = create_labels(encQ_out.size(0), previous_max_label)
        loss = loss_fn(all_enc, labels, enqueue_mask=enqueue_mask)

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pbar.set_description("loss=%.5f" % loss.item())
        update_records(
            loss, loss_fn, optimizer, record_keeper, global_iteration["iter"]
        )
        global_iteration["iter"] += 1

# %% [markdown]
# ##### Start Tensorboard and delete old folders.

# %%
# !rm -rfv example_logs example_tensorboard example_saved_models
# %load_ext tensorboard
# %tensorboard --logdir example_tensorboard
# Out:
# removed 'example_logs/loss_function_CrossBatchMemory.csv'
# removed 'example_logs/logs.db'
# removed 'example_logs/optimizer_SGD.csv'
# removed 'example_logs/loss_histories.csv'
# removed 'example_logs/accuracy.csv'
# removed directory 'example_logs'
# removed 'example_tensorboard/events.out.tfevents.1712249090.aarya-ExcaliburOMEN.12019.0'
# removed directory 'example_tensorboard'
# removed 'example_saved_models/encQ_best.pth'
# removed directory 'example_saved_models'
#       <iframe id="tensorboard-frame-98e705b94db44440" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-98e705b94db44440");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
batch_size = 128
lr = 0.03
paramK_momentum = 0.99
memory_size = 4096
num_epochs = 1200
knn_k = 200
knn_t = 0.1

(
    train_dataset,
    train_dataset_for_eval,
    val_dataset,
    train_loader,
    train_loader_for_eval,
    val_loader,
) = create_dataset(batch_size)

encQ = create_encoder()
encK = create_encoder()

# copy params from encQ into encK
copy_params(encQ, encK)

optimizer = torch.optim.SGD(encQ.parameters(), lr, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_epochs)

###########################################################
### Set the loss function and the (optional) miner here ###
###########################################################
loss_fn = losses.CrossBatchMemory(
    loss=losses.NTXentLoss(temperature=0.1), embedding_size=128, memory_size=memory_size
)

dataset_dict = {"train": train_dataset_for_eval, "val": val_dataset}
record_keeper, _, _ = logging_presets.get_record_keeper(
    "example_logs", "example_tensorboard"
)
hooks = logging_presets.get_hook_container(record_keeper)

# first check untrained performance
epoch = 0
best_accuracy = test(
    encQ, train_loader_for_eval, val_loader, epoch, knn_k, knn_t, record_keeper
)

global_iteration = {"iter": 0}
for epoch in range(1, num_epochs + 1):
    logging.info("Starting epoch {}".format(epoch))
    train(
        encQ,
        encK,
        paramK_momentum,
        loss_fn,
        optimizer,
        train_loader,
        record_keeper,
        global_iteration,
    )
    curr_accuracy = test(
        encQ, train_loader_for_eval, val_loader, epoch, knn_k, knn_t, record_keeper
    )
    if curr_accuracy > best_accuracy:
        best_accuracy = curr_accuracy
        save_model(encQ)
    scheduler.step()
# Out:
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.21it/s]
# Test Epoch 0: Acc@1:17.14%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1
# loss=6.89374: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.48it/s]
# Test Epoch 1: Acc@1:15.14%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 2
# loss=7.06110: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 2: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 3
# loss=6.35679: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 3: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 4
# loss=5.95951: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 4: Acc@1:18.29%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 5
# loss=5.81099: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 5: Acc@1:18.86%: 100%|██████████| 3/3 [00:01<00:00,  1.79it/s]
# INFO:root:Starting epoch 6
# loss=5.82553: 100%|██████████| 11/11 [00:08<00:00,  1.28it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 6: Acc@1:20.57%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 7
# loss=5.70487: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 7: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 8
# loss=5.68925: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 8: Acc@1:18.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 9
# loss=5.70868: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 9: Acc@1:19.71%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 10
# loss=5.71931: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 10: Acc@1:20.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 11
# loss=5.75712: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 11: Acc@1:19.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 12
# loss=5.70599: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 12: Acc@1:20.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 13
# loss=5.80602: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 13: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 14
# loss=5.77199: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 14: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 15
# loss=5.79476: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 15: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 16
# loss=5.68805: 100%|██████████| 11/11 [00:08<00:00,  1.27it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 16: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 17
# loss=5.96681: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 17: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 18
# loss=5.93719: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 18: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 19
# loss=6.05817: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 19: Acc@1:22.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 20
# loss=6.08569: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 20: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 21
# loss=6.05115: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 21: Acc@1:22.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 22
# loss=6.10469: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 22: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 23
# loss=6.13626: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 23: Acc@1:16.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 24
# loss=6.07738: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 24: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 25
# loss=6.01076: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 25: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 26
# loss=6.23540: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 26: Acc@1:22.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 27
# loss=6.09069: 100%|██████████| 11/11 [00:09<00:00,  1.18it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 27: Acc@1:21.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 28
# loss=6.15184: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 28: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 29
# loss=6.12615: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 29: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 30
# loss=6.12162: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 30: Acc@1:22.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 31
# loss=6.17572: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 31: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 32
# loss=6.11293: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 32: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 33
# loss=6.18363: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 33: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 34
# loss=6.23615: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 34: Acc@1:20.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 35
# loss=6.23202: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 35: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 36
# loss=6.24328: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 36: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 37
# loss=6.17214: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 37: Acc@1:22.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 38
# loss=6.27086: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 38: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 39
# loss=6.26314: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 39: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 40
# loss=6.16364: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 40: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 41
# loss=6.13312: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 41: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 42
# loss=6.09083: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 42: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 43
# loss=6.14142: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 43: Acc@1:20.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 44
# loss=6.25926: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 44: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 45
# loss=6.17945: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 45: Acc@1:22.86%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 46
# loss=6.28143: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 46: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 47
# loss=6.39058: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 47: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 48
# loss=6.25039: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 48: Acc@1:21.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 49
# loss=6.19404: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 49: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 50
# loss=6.08888: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 50: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 51
# loss=6.28740: 100%|██████████| 11/11 [00:09<00:00,  1.17it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 51: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 52
# loss=6.12803: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 52: Acc@1:20.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 53
# loss=6.28028: 100%|██████████| 11/11 [00:09<00:00,  1.15it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 53: Acc@1:21.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 54
# loss=6.17248: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 54: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 55
# loss=6.27182: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 55: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 56
# loss=6.21770: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 56: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 57
# loss=6.26036: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 57: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 58
# loss=6.24078: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 58: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 59
# loss=6.35361: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 59: Acc@1:21.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 60
# loss=6.14684: 100%|██████████| 11/11 [00:08<00:00,  1.26it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 60: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 61
# loss=6.18439: 100%|██████████| 11/11 [00:26<00:00,  2.38s/it]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.22it/s]
# Test Epoch 61: Acc@1:25.14%: 100%|██████████| 3/3 [00:03<00:00,  1.22s/it]
# INFO:root:Starting epoch 62
# loss=6.16719: 100%|██████████| 11/11 [00:47<00:00,  4.33s/it]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.22it/s]
# Test Epoch 62: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 63
# loss=6.36209: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 63: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 64
# loss=6.13850: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 64: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 65
# loss=6.21474: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 65: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 66
# loss=6.27247: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 66: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 67
# loss=6.24355: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 67: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 68
# loss=6.23223: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 68: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 69
# loss=6.10945: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 69: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 70
# loss=6.09415: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 70: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 71
# loss=6.11267: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 71: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 72
# loss=6.28719: 100%|██████████| 11/11 [00:50<00:00,  4.60s/it]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.88it/s]
# Test Epoch 72: Acc@1:25.14%: 100%|██████████| 3/3 [00:04<00:00,  1.39s/it]
# INFO:root:Starting epoch 73
# loss=6.01053: 100%|██████████| 11/11 [00:24<00:00,  2.19s/it]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 73: Acc@1:25.43%: 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
# INFO:root:Starting epoch 74
# loss=6.23292: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 74: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 75
# loss=6.04578: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 75: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 76
# loss=5.93442: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 76: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 77
# loss=6.19581: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 77: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 78
# loss=6.09525: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 78: Acc@1:22.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 79
# loss=5.98462: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 79: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 80
# loss=6.08203: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 80: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 81
# loss=6.07872: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 81: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 82
# loss=5.99249: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 82: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 83
# loss=6.05041: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 83: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 84
# loss=6.12263: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 84: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 85
# loss=6.11487: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 85: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 86
# loss=5.87877: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 86: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 87
# loss=6.07103: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 87: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 88
# loss=6.01109: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 88: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 89
# loss=6.09764: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 89: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 90
# loss=6.06072: 100%|██████████| 11/11 [00:10<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.21it/s]
# Test Epoch 90: Acc@1:22.86%: 100%|██████████| 3/3 [00:05<00:00,  1.80s/it]
# INFO:root:Starting epoch 91
# loss=6.00310: 100%|██████████| 11/11 [00:12<00:00,  1.10s/it]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 91: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 92
# loss=6.07168: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 92: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 93
# loss=6.03268: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 93: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 94
# loss=5.97414: 100%|██████████| 11/11 [00:09<00:00,  1.14it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 94: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 95
# loss=6.16086: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 95: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 96
# loss=5.94512: 100%|██████████| 11/11 [00:09<00:00,  1.21it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 96: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 97
# loss=5.95779: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 97: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 98
# loss=6.01842: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 98: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 99
# loss=5.92698: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 99: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 100
# loss=6.01629: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 100: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 101
# loss=5.91833: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 101: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 102
# loss=5.99744: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 102: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 103
# loss=6.05142: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 103: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 104
# loss=6.03856: 100%|██████████| 11/11 [00:07<00:00,  1.40it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 104: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 105
# loss=5.97848: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 105: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 106
# loss=5.98068: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 106: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 107
# loss=5.92444: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 107: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 108
# loss=5.93483: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 108: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 109
# loss=6.00509: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 109: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 110
# loss=5.96071: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 110: Acc@1:22.00%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 111
# loss=5.86786: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 111: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 112
# loss=5.83935: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 112: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 113
# loss=5.98569: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 113: Acc@1:23.71%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 114
# loss=5.82863: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 114: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.68it/s]
# INFO:root:Starting epoch 115
# loss=6.06458: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 115: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 116
# loss=5.81161: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 116: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 117
# loss=5.70197: 100%|██████████| 11/11 [00:09<00:00,  1.19it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.52it/s]
# Test Epoch 117: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 118
# loss=5.93269: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# Test Epoch 118: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 119
# loss=5.93877: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.21it/s]
# Test Epoch 119: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 120
# loss=5.77540: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 120: Acc@1:23.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 121
# loss=5.82265: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 121: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 122
# loss=5.75018: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 122: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 123
# loss=5.97640: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 123: Acc@1:26.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 124
# loss=5.79353: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 124: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 125
# loss=5.95091: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 125: Acc@1:20.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 126
# loss=6.01990: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 126: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 127
# loss=5.78920: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 127: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 128
# loss=5.79254: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 128: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 129
# loss=5.75648: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 129: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 130
# loss=5.62526: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 130: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 131
# loss=5.64449: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.46it/s]
# Test Epoch 131: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.78it/s]
# INFO:root:Starting epoch 132
# loss=5.82234: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 132: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 133
# loss=5.79385: 100%|██████████| 11/11 [00:09<00:00,  1.22it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 133: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 134
# loss=5.89199: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 134: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 135
# loss=5.80362: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 135: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 136
# loss=5.85092: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 136: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 137
# loss=5.78233: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 137: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 138
# loss=5.81186: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 138: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 139
# loss=5.81834: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 139: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 140
# loss=5.66608: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 140: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 141
# loss=5.78320: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 141: Acc@1:24.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 142
# loss=5.62160: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 142: Acc@1:23.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 143
# loss=5.64158: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 143: Acc@1:25.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 144
# loss=5.66219: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 144: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 145
# loss=5.53785: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 145: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 146
# loss=5.81427: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# Test Epoch 146: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 147
# loss=5.94172: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 147: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 148
# loss=5.69641: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 148: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 149
# loss=5.93616: 100%|██████████| 11/11 [00:08<00:00,  1.28it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 149: Acc@1:24.00%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 150
# loss=5.64260: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 150: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 151
# loss=5.62354: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 151: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 152
# loss=5.51227: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 152: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 153
# loss=5.71741: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 153: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 154
# loss=5.77495: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 154: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 155
# loss=5.64522: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 155: Acc@1:25.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 156
# loss=5.80217: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 156: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 157
# loss=5.38374: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 157: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 158
# loss=5.87160: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 158: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 159
# loss=5.59761: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 159: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 160
# loss=5.59015: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 160: Acc@1:26.86%: 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
# INFO:root:Starting epoch 161
# loss=5.70971: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 161: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 162
# loss=5.55935: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 162: Acc@1:27.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 163
# loss=5.60600: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 163: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 164
# loss=5.64355: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 164: Acc@1:28.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 165
# loss=5.51102: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 165: Acc@1:24.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 166
# loss=5.56036: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 166: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 167
# loss=5.50995: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 167: Acc@1:29.14%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 168
# loss=5.57260: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 168: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 169
# loss=5.69251: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 169: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 170
# loss=5.50621: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 170: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 171
# loss=5.77378: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 171: Acc@1:28.00%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 172
# loss=5.74657: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 172: Acc@1:26.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 173
# loss=5.72679: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# Test Epoch 173: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 174
# loss=5.23692: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 174: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 175
# loss=5.53619: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 175: Acc@1:24.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 176
# loss=5.52762: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 176: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 177
# loss=5.45084: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# Test Epoch 177: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 178
# loss=5.54092: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 178: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 179
# loss=5.55737: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 179: Acc@1:28.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 180
# loss=5.20814: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 180: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 181
# loss=5.42993: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 181: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 182
# loss=5.40694: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 182: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 183
# loss=5.31608: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 183: Acc@1:29.14%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 184
# loss=5.56043: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 184: Acc@1:28.00%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 185
# loss=5.43425: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 185: Acc@1:25.14%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 186
# loss=5.42217: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 186: Acc@1:29.43%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 187
# loss=5.50547: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 187: Acc@1:28.00%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 188
# loss=5.31643: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 188: Acc@1:27.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 189
# loss=5.36661: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 189: Acc@1:26.29%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 190
# loss=5.73254: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 190: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 191
# loss=5.47740: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 191: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 192
# loss=5.31963: 100%|██████████| 11/11 [00:08<00:00,  1.28it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 192: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 193
# loss=5.49156: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 193: Acc@1:28.29%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 194
# loss=5.47106: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.62it/s]
# Test Epoch 194: Acc@1:29.43%: 100%|██████████| 3/3 [00:01<00:00,  1.88it/s]
# INFO:root:Starting epoch 195
# loss=5.81764: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 195: Acc@1:30.00%: 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
# INFO:root:Starting epoch 196
# loss=5.48188: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 196: Acc@1:28.57%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 197
# loss=5.32765: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 197: Acc@1:29.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 198
# loss=5.33088: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 198: Acc@1:28.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 199
# loss=5.35228: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 199: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 200
# loss=5.71130: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 200: Acc@1:30.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 201
# loss=5.42881: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 201: Acc@1:29.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 202
# loss=5.64831: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 202: Acc@1:28.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 203
# loss=5.57715: 100%|██████████| 11/11 [00:08<00:00,  1.30it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 203: Acc@1:28.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 204
# loss=5.22859: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 204: Acc@1:29.71%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 205
# loss=5.32477: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 205: Acc@1:26.57%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 206
# loss=5.32742: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.61it/s]
# Test Epoch 206: Acc@1:27.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 207
# ...
# INFO:root:Starting epoch 1133
# loss=2.58173: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.73it/s]
# Test Epoch 1133: Acc@1:38.00%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1134
# loss=2.83323: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1134: Acc@1:38.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1135
# loss=2.44259: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1135: Acc@1:37.71%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1136
# loss=2.63806: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 1136: Acc@1:38.00%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1137
# loss=2.56317: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 1137: Acc@1:37.71%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1138
# loss=2.79013: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1138: Acc@1:37.14%: 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
# INFO:root:Starting epoch 1139
# loss=2.67790: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1139: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1140
# loss=2.73156: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1140: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1141
# loss=2.82632: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 1141: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1142
# loss=2.78456: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 1142: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1143
# loss=2.62040: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1143: Acc@1:37.71%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 1144
# loss=2.55335: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1144: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1145
# loss=2.75761: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1145: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1146
# loss=2.71227: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1146: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1147
# loss=2.60974: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1147: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1148
# loss=2.56685: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 1148: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1149
# loss=2.54973: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 1149: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1150
# loss=2.69822: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1150: Acc@1:37.14%: 100%|██████████| 3/3 [00:02<00:00,  1.47it/s]
# INFO:root:Starting epoch 1151
# loss=2.69236: 100%|██████████| 11/11 [00:09<00:00,  1.18it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.71it/s]
# Test Epoch 1151: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1152
# loss=2.85040: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 1152: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1153
# loss=2.78591: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1153: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1154
# loss=2.66203: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1154: Acc@1:37.71%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1155
# loss=2.91530: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1155: Acc@1:38.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1156
# loss=2.57945: 100%|██████████| 11/11 [00:08<00:00,  1.31it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1156: Acc@1:38.29%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1157
# loss=2.63926: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1157: Acc@1:37.71%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1158
# loss=2.53644: 100%|██████████| 11/11 [00:09<00:00,  1.20it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1158: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1159
# loss=2.74778: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 1159: Acc@1:37.71%: 100%|██████████| 3/3 [00:01<00:00,  1.81it/s]
# INFO:root:Starting epoch 1160
# loss=2.50284: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1160: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1161
# loss=2.79538: 100%|██████████| 11/11 [00:08<00:00,  1.29it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.54it/s]
# Test Epoch 1161: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1162
# loss=2.75407: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1162: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1163
# loss=2.52261: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1163: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1164
# loss=2.69345: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1164: Acc@1:37.71%: 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
# INFO:root:Starting epoch 1165
# loss=2.81662: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1165: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1166
# loss=2.60551: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1166: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1167
# loss=2.68759: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:02<00:00,  1.72it/s]
# Test Epoch 1167: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1168
# loss=2.62383: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1168: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1169
# loss=2.50090: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1169: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1170
# loss=2.49726: 100%|██████████| 11/11 [00:09<00:00,  1.16it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.55it/s]
# Test Epoch 1170: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1171
# loss=2.54491: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1171: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1172
# loss=2.54963: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1172: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 1173
# loss=2.70020: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 1173: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1174
# loss=2.58036: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1174: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1175
# loss=2.59237: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1175: Acc@1:37.14%: 100%|██████████| 3/3 [00:02<00:00,  1.26it/s]
# INFO:root:Starting epoch 1176
# loss=2.59385: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1176: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1177
# loss=2.54145: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1177: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1178
# loss=2.51344: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1178: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1179
# loss=2.61790: 100%|██████████| 11/11 [00:08<00:00,  1.32it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1179: Acc@1:36.86%: 100%|██████████| 3/3 [00:02<00:00,  1.25it/s]
# INFO:root:Starting epoch 1180
# loss=2.52958: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1180: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1181
# loss=2.63093: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1181: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1182
# loss=2.69609: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1182: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1183
# loss=2.73604: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.60it/s]
# Test Epoch 1183: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1184
# loss=2.58476: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1184: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1185
# loss=2.51744: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1185: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1186
# loss=2.66660: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1186: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1187
# loss=2.76571: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1187: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1188
# loss=2.85072: 100%|██████████| 11/11 [00:07<00:00,  1.39it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1188: Acc@1:37.14%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1189
# loss=2.71204: 100%|██████████| 11/11 [00:08<00:00,  1.28it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 1189: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1190
# loss=2.64525: 100%|██████████| 11/11 [00:09<00:00,  1.18it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 1190: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1191
# loss=2.91559: 100%|██████████| 11/11 [00:08<00:00,  1.37it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1191: Acc@1:37.43%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1192
# loss=2.67430: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1192: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.82it/s]
# INFO:root:Starting epoch 1193
# loss=2.75820: 100%|██████████| 11/11 [00:07<00:00,  1.38it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1193: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.87it/s]
# INFO:root:Starting epoch 1194
# loss=2.74387: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.59it/s]
# Test Epoch 1194: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.86it/s]
# INFO:root:Starting epoch 1195
# loss=2.77128: 100%|██████████| 11/11 [00:08<00:00,  1.33it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.53it/s]
# Test Epoch 1195: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.84it/s]
# INFO:root:Starting epoch 1196
# loss=2.68804: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1196: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.83it/s]
# INFO:root:Starting epoch 1197
# loss=2.54645: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.58it/s]
# Test Epoch 1197: Acc@1:36.86%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1198
# loss=2.49404: 100%|██████████| 11/11 [00:08<00:00,  1.34it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1198: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]
# INFO:root:Starting epoch 1199
# loss=2.57822: 100%|██████████| 11/11 [00:08<00:00,  1.36it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# Test Epoch 1199: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.80it/s]
# INFO:root:Starting epoch 1200
# loss=2.69256: 100%|██████████| 11/11 [00:08<00:00,  1.35it/s]
# Feature extracting: 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]
# Test Epoch 1200: Acc@1:36.57%: 100%|██████████| 3/3 [00:01<00:00,  1.85it/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
accuracy_df = pd.read_csv('example_logs/accuracy.csv')
accuracy = accuracy_df['knn_monitor_accuracy']
plt.plot(accuracy)

plt.title('KNN Monitored Accuracy Plot')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.show()
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
loss_df = pd.read_csv('example_logs/loss_histories.csv')
loss = loss_df['loss']
plt.plot(loss)

plt.title('Loss Plot')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.show()
