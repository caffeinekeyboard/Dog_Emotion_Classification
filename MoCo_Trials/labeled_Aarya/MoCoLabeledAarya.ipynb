# %% [markdown]
# #### Implementation of Momentum Contrast for Unsupervised Visual Representation Learning, to analyse and detect dog emotions.
# - Paper : https://arxiv.org/abs/1911.05722
# - Code : https://github.com/facebookresearch/moco

# %%
import logging
import os 
import random
from functools import partial

import torch
from PIL import ImageFilter
from torchvision import datasets, transforms
from torchvision.models import resnet 
from tqdm import tqdm 
import numpy as np

from pytorch_metric_learning import losses
from pytorch_metric_learning.utils import logging_presets

logging.getLogger().setLevel(logging.INFO)

device = torch.device("cuda")

# %% [markdown]
# ##### Augmentation functions taken straight from https://github.com/facebookresearch/moco
# - Two-Crops Transform
# - Gaussian Blur

# %%
class TwoCropsTransform:
    """Take two random crops of one image as the query and key."""

    def __init__(self, base_transform):
        self.base_transform = base_transform

    def __call__(self, x):
        q = self.base_transform(x)
        k = self.base_transform(x)
        return [q, k]
    
class GaussianBlur(object):
    """Gaussian blur augmentation in SimCLR https://arxiv.org/abs/2002.05709"""

    def __init__(self, sigma=[0.1, 2.0]):
        self.sigma = sigma

    def __call__(self, x):
        sigma = random.uniform(self.sigma[0], self.sigma[1])
        x = x.filter(ImageFilter.GaussianBlur(radius=sigma))
        return x

# %% [markdown]
# ##### Dataset creation function.
# - Reduces overhead variable accumulation.
# - Easy to steal from MoCo :-)

# %%
MEAN = [0.47365573, 0.4402452, 0.38663769]
STD = [0.26914782, 0.26083042, 0.2624779]

# %%
def create_dataset(batch_size):
    normalize = transforms.Normalize(MEAN, STD)
    
    train_transform = transforms.Compose(
        [
            transforms.RandomResizedCrop(32),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.RandomApply([transforms.ColorJitter(0.4, 0.4, 0.4, 0.1)], p=0.8),
            transforms.RandomGrayscale(p=0.2),
            transforms.ToTensor(),
            normalize,
        ]
    )

    train_transform = TwoCropsTransform(train_transform)
    val_transform = transforms.Compose([transforms.Resize((32, 32)), transforms.ToTensor(), normalize])
    
    train_dir = 'data/train/'
    val_dir = 'data/validation/'
    test_dir = 'data/test/'
    
    train_dataset = datasets.ImageFolder(
        train_dir , transform=train_transform
    )
    train_dataset_for_eval = datasets.ImageFolder(
        val_dir, transform=val_transform
    )
    val_dataset = datasets.ImageFolder(
        test_dir, transform=val_transform
    )

    train_loader = torch.utils.data.DataLoader(
        train_dataset,
        batch_size=batch_size,
        shuffle=True,
        num_workers=2,
        pin_memory=True,
        drop_last=True,
    )

    train_loader_for_eval = torch.utils.data.DataLoader(
        train_dataset_for_eval,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    val_loader = torch.utils.data.DataLoader(
        val_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=2,
        pin_memory=True,
        drop_last=False,
    )

    return (
        train_dataset,
        train_dataset_for_eval,
        val_dataset,
        train_loader,
        train_loader_for_eval,
        val_loader,
    )

# %% [markdown]
# ##### SplitBatchNorm: simulate multi-gpu behavior of BatchNorm in one gpu by splitting alone the batch dimension.
# - Yanked from https://github.com/davidcpage/cifar10-fast/blob/master/torch_backend.py

# %%
class SplitBatchNorm(torch.nn.BatchNorm2d):
    def __init__(self, num_features, num_splits, **kw):
        super().__init__(num_features, **kw)
        self.num_splits = num_splits

    def forward(self, input):
        N, C, H, W = input.shape
        if self.training or not self.track_running_stats:
            running_mean_split = self.running_mean.repeat(self.num_splits)
            running_var_split = self.running_var.repeat(self.num_splits)
            outcome = torch.nn.functional.batch_norm(
                input.view(-1, C * self.num_splits, H, W),
                running_mean_split,
                running_var_split,
                self.weight.repeat(self.num_splits),
                self.bias.repeat(self.num_splits),
                True,
                self.momentum,
                self.eps,
            ).view(N, C, H, W)
            self.running_mean.data.copy_(
                running_mean_split.view(self.num_splits, C).mean(dim=0)
            )
            self.running_var.data.copy_(
                running_var_split.view(self.num_splits, C).mean(dim=0)
            )
            return outcome
        else:
            return torch.nn.functional.batch_norm(
                input,
                self.running_mean,
                self.running_var,
                self.weight,
                self.bias,
                False,
                self.momentum,
                self.eps,
            )

# %% [markdown]
# ##### Model definition and code for copying params from encQ to encK.

# %%
class ModelBase(torch.nn.Module):
    """
    Common CIFAR ResNet recipe.
    Comparing with ImageNet ResNet recipe, it:
    (i) replaces conv1 with kernel=3, str=1
    (ii) removes pool1
    """

    def __init__(self, feature_dim=128, arch="resnet18", bn_splits=8):
        super(ModelBase, self).__init__()

        # use split batchnorm
        norm_layer = (
            partial(SplitBatchNorm, num_splits=bn_splits)
            if bn_splits > 1
            else torch.nn.BatchNorm2d
        )
        resnet_arch = getattr(resnet, arch)
        net = resnet_arch(num_classes=feature_dim, norm_layer=norm_layer)

        self.net = []
        for name, module in net.named_children():
            if name == "conv1":
                module = torch.nn.Conv2d(
                    3, 64, kernel_size=3, stride=1, padding=1, bias=False
                )
            if isinstance(module, torch.nn.MaxPool2d):
                continue
            if isinstance(module, torch.nn.Linear):
                self.net.append(torch.nn.Flatten(1))
            self.net.append(module)

        self.net = torch.nn.Sequential(*self.net)

    def forward(self, x):
        x = self.net(x)
        # note: not normalized here
        return x


def copy_params(encQ, encK, m=None):
    if m is None:
        for param_q, param_k in zip(encQ.parameters(), encK.parameters()):
            param_k.data.copy_(param_q.data)  # initialize
            param_k.requires_grad = False  # not update by gradient
    else:
        for param_q, param_k in zip(encQ.parameters(), encK.parameters()):
            param_k.data = param_k.data * m + param_q.data * (1.0 - m)


def create_encoder():
    model = ModelBase()
    model = torch.nn.DataParallel(model)
    model.to(device)
    return model

# %% [markdown]
# ##### Evaluation Functions.

# %%
def test(net, memory_data_loader, test_data_loader, epoch, knn_k, knn_t, record_keeper):
    net.eval()
    classes = len(memory_data_loader.dataset.classes)
    total_top1, total_num, feature_bank = 0.0, 0, []
    with torch.no_grad():
        # generate feature bank
        for data, target in tqdm(memory_data_loader, desc="Feature extracting"):
            feature = net(data.cuda(non_blocking=True))
            feature = torch.nn.functional.normalize(feature, dim=1)
            feature_bank.append(feature)
        # [D, N]
        feature_bank = torch.cat(feature_bank, dim=0).t().contiguous()
        # [N]
        feature_labels = torch.tensor(
            memory_data_loader.dataset.targets, device=feature_bank.device
        )
        # loop test data to predict the label by weighted knn search
        test_bar = tqdm(test_data_loader)
        for data, target in test_bar:
            data, target = data.cuda(non_blocking=True), target.cuda(non_blocking=True)
            feature = net(data)
            feature = torch.nn.functional.normalize(feature, dim=1)

            pred_labels = knn_predict(
                feature, feature_bank, feature_labels, classes, knn_k, knn_t
            )

            total_num += data.size(0)
            total_top1 += (pred_labels[:, 0] == target).float().sum().item()
            acc = total_top1 / total_num * 100
            test_bar.set_description("Test Epoch {}: Acc@1:{:.2f}%".format(epoch, acc))

    record_keeper.update_records(
        {"knn_monitor_accuracy": acc},
        epoch,
        parent_name="accuracy",
    )
    record_keeper.save_records()
    return acc


def knn_predict(feature, feature_bank, feature_labels, classes, knn_k, knn_t):
    # compute cos similarity between each feature vector and feature bank ---> [B, N]
    sim_matrix = torch.mm(feature, feature_bank)
    # [B, K]
    sim_weight, sim_indices = sim_matrix.topk(k=knn_k, dim=-1)
    # [B, K]
    sim_labels = torch.gather(
        feature_labels.expand(feature.size(0), -1), dim=-1, index=sim_indices
    )
    sim_weight = (sim_weight / knn_t).exp()

    # counts for each class
    one_hot_label = torch.zeros(
        feature.size(0) * knn_k, classes, device=sim_labels.device
    )
    # [B*K, C]
    one_hot_label = one_hot_label.scatter(
        dim=-1, index=sim_labels.view(-1, 1), value=1.0
    )
    # weighted score ---> [B, C]
    pred_scores = torch.sum(
        one_hot_label.view(feature.size(0), -1, classes) * sim_weight.unsqueeze(dim=-1),
        dim=1,
    )

    pred_labels = pred_scores.argsort(dim=-1, descending=True)
    return pred_labels

# %% [markdown]
# ##### Training and logging functions.

# %%
def update_records(loss, loss_fn, optimizer, record_keeper, global_iteration):
    def optimizer_custom_attr_func(opt):
        return {"lr": opt.param_groups[0]["lr"]}

    record_these = [
        [{"loss": loss.item()}, {"parent_name": "loss_histories"}],
        [{"loss_function": loss_fn}, {"recursive_types": [torch.nn.Module]}],
        [{"optimizer": optimizer}, {"custom_attr_func": optimizer_custom_attr_func}],
    ]
    for record, kwargs in record_these:
        record_keeper.update_records(record, global_iteration, **kwargs)


def save_model(encQ):
    model_folder = "example_saved_models"
    if not os.path.exists(model_folder):
        os.makedirs(model_folder)
    torch.save(encQ.state_dict(), "{}/encQ_best.pth".format(model_folder))



def batch_shuffle_single_gpu(x):
    """
    Batch shuffle, for making use of BatchNorm.
    """
    # random shuffle index
    idx_shuffle = torch.randperm(x.shape[0]).cuda()

    # index for restoring
    idx_unshuffle = torch.argsort(idx_shuffle)

    return x[idx_shuffle], idx_unshuffle



def batch_unshuffle_single_gpu(x, idx_unshuffle):
    """
    Undo batch shuffle.
    """
    return x[idx_unshuffle]


def create_labels(num_pos_pairs, previous_max_label):
    # create labels that indicate what the positive pairs are
    labels = torch.arange(0, num_pos_pairs)
    labels = torch.cat((labels, labels)).to(device)
    # add an offset so that the labels do not overlap with any labels in the memory queue
    labels += previous_max_label + 1
    # we want to enqueue the output of encK, which is the 2nd half of the batch
    enqueue_mask = torch.zeros(len(labels)).bool()
    enqueue_mask[num_pos_pairs:] = True
    return labels, enqueue_mask


def train(
    encQ,
    encK,
    paramK_momentum,
    loss_fn,
    optimizer,
    train_loader,
    record_keeper,
    global_iteration,
):
    encQ.train()
    pbar = tqdm(train_loader)
    for images, _ in pbar:
        previous_max_label = torch.max(loss_fn.label_memory)
        imgQ = images[0].to(device)
        imgK = images[1].to(device)

        # compute output
        encQ_out = encQ(imgQ)
        with torch.no_grad():  # no gradient to keys
            copy_params(encQ, encK, m=paramK_momentum)
            imgK, idx_unshuffle = batch_shuffle_single_gpu(imgK)
            encK_out = encK(imgK)
            encK_out = batch_unshuffle_single_gpu(encK_out, idx_unshuffle)

        all_enc = torch.cat([encQ_out, encK_out], dim=0)
        labels, enqueue_mask = create_labels(encQ_out.size(0), previous_max_label)
        loss = loss_fn(all_enc, labels, enqueue_mask=enqueue_mask)

        # compute gradient and do SGD step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        pbar.set_description("loss=%.5f" % loss.item())
        update_records(
            loss, loss_fn, optimizer, record_keeper, global_iteration["iter"]
        )
        global_iteration["iter"] += 1

# %% [markdown]
# ##### Start Tensorboard and delete old folders.

# %%
# !rm -rfv example_logs example_tensorboard example_saved_models
# %load_ext tensorboard
# %tensorboard --logdir example_tensorboard
# Out:
# removed 'example_logs/loss_function_CrossBatchMemory.csv'
# removed 'example_logs/logs.db'
# removed 'example_logs/optimizer_SGD.csv'
# removed 'example_logs/loss_histories.csv'
# removed 'example_logs/accuracy.csv'
# removed directory 'example_logs'
# removed 'example_tensorboard/events.out.tfevents.1712132974.aarya-ExcaliburOMEN.15537.0'
# removed directory 'example_tensorboard'
# removed 'example_saved_models/encQ_best.pth'
# removed directory 'example_saved_models'
# Reusing TensorBoard on port 6006 (pid 42112), started 0:23:23 ago. (Use '!kill 42112' to kill it.)
#       <iframe id="tensorboard-frame-8927f4498939c050" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8927f4498939c050");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
batch_size = 256
lr = 0.03
paramK_momentum = 0.99
memory_size = 4096
num_epochs = 200
knn_k = 200
knn_t = 0.1

(
    train_dataset,
    train_dataset_for_eval,
    val_dataset,
    train_loader,
    train_loader_for_eval,
    val_loader,
) = create_dataset(batch_size)

encQ = create_encoder()
encK = create_encoder()

# copy params from encQ into encK
copy_params(encQ, encK)

optimizer = torch.optim.SGD(encQ.parameters(), lr, momentum=0.9, weight_decay=5e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, num_epochs)

###########################################################
### Set the loss function and the (optional) miner here ###
###########################################################
loss_fn = losses.CrossBatchMemory(
    loss=losses.NTXentLoss(temperature=0.1), embedding_size=128, memory_size=memory_size
)

dataset_dict = {"train": train_dataset_for_eval, "val": val_dataset}
record_keeper, _, _ = logging_presets.get_record_keeper(
    "example_logs", "example_tensorboard"
)
hooks = logging_presets.get_hook_container(record_keeper)

# first check untrained performance
epoch = 0
best_accuracy = test(
    encQ, train_loader_for_eval, val_loader, epoch, knn_k, knn_t, record_keeper
)

global_iteration = {"iter": 0}
for epoch in range(1, num_epochs + 1):
    logging.info("Starting epoch {}".format(epoch))
    train(
        encQ,
        encK,
        paramK_momentum,
        loss_fn,
        optimizer,
        train_loader,
        record_keeper,
        global_iteration,
    )
    curr_accuracy = test(
        encQ, train_loader_for_eval, val_loader, epoch, knn_k, knn_t, record_keeper
    )
    if curr_accuracy > best_accuracy:
        best_accuracy = curr_accuracy
        save_model(encQ)
    scheduler.step()
# Out:
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.48s/it]
# Test Epoch 0: Acc@1:16.29%: 100%|██████████| 2/2 [00:03<00:00,  1.55s/it]
# INFO:root:Starting epoch 1
# loss=7.04836: 100%|██████████| 5/5 [00:05<00:00,  1.20s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.20it/s]
# Test Epoch 1: Acc@1:18.29%: 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]
# INFO:root:Starting epoch 2
# loss=7.59313: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# Test Epoch 2: Acc@1:17.71%: 100%|██████████| 2/2 [00:01<00:00,  1.01it/s]
# INFO:root:Starting epoch 3
# loss=7.82230: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.21s/it]
# Test Epoch 3: Acc@1:16.86%: 100%|██████████| 2/2 [00:02<00:00,  1.41s/it]
# INFO:root:Starting epoch 4
# loss=7.59961: 100%|██████████| 5/5 [00:07<00:00,  1.55s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# Test Epoch 4: Acc@1:19.43%: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# INFO:root:Starting epoch 5
# loss=7.21379: 100%|██████████| 5/5 [00:07<00:00,  1.44s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Test Epoch 5: Acc@1:21.14%: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# INFO:root:Starting epoch 6
# loss=7.09319: 100%|██████████| 5/5 [00:05<00:00,  1.13s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.13it/s]
# Test Epoch 6: Acc@1:18.29%: 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# INFO:root:Starting epoch 7
# loss=6.89378: 100%|██████████| 5/5 [00:07<00:00,  1.48s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# Test Epoch 7: Acc@1:19.14%: 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
# INFO:root:Starting epoch 8
# loss=6.71119: 100%|██████████| 5/5 [00:06<00:00,  1.29s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 8: Acc@1:17.71%: 100%|██████████| 2/2 [00:02<00:00,  1.03s/it]
# INFO:root:Starting epoch 9
# loss=6.67686: 100%|██████████| 5/5 [00:08<00:00,  1.77s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Test Epoch 9: Acc@1:17.71%: 100%|██████████| 2/2 [00:03<00:00,  1.52s/it]
# INFO:root:Starting epoch 10
# loss=6.66225: 100%|██████████| 5/5 [00:06<00:00,  1.21s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 10: Acc@1:19.14%: 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# INFO:root:Starting epoch 11
# loss=6.49191: 100%|██████████| 5/5 [00:08<00:00,  1.63s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Test Epoch 11: Acc@1:19.43%: 100%|██████████| 2/2 [00:03<00:00,  1.50s/it]
# INFO:root:Starting epoch 12
# loss=6.58536: 100%|██████████| 5/5 [00:07<00:00,  1.44s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it]
# Test Epoch 12: Acc@1:19.14%: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# INFO:root:Starting epoch 13
# loss=6.58293: 100%|██████████| 5/5 [00:06<00:00,  1.28s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Test Epoch 13: Acc@1:18.57%: 100%|██████████| 2/2 [00:03<00:00,  1.60s/it]
# INFO:root:Starting epoch 14
# loss=6.39867: 100%|██████████| 5/5 [00:06<00:00,  1.30s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 14: Acc@1:22.86%: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# INFO:root:Starting epoch 15
# loss=6.49699: 100%|██████████| 5/5 [00:06<00:00,  1.22s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 15: Acc@1:19.71%: 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]
# INFO:root:Starting epoch 16
# loss=6.42942: 100%|██████████| 5/5 [00:07<00:00,  1.54s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 16: Acc@1:20.29%: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it]
# INFO:root:Starting epoch 17
# loss=6.45027: 100%|██████████| 5/5 [00:05<00:00,  1.15s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# Test Epoch 17: Acc@1:18.29%: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# INFO:root:Starting epoch 18
# loss=6.50249: 100%|██████████| 5/5 [00:09<00:00,  1.84s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Test Epoch 18: Acc@1:20.29%: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# INFO:root:Starting epoch 19
# loss=6.43102: 100%|██████████| 5/5 [00:05<00:00,  1.19s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# Test Epoch 19: Acc@1:18.57%: 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# INFO:root:Starting epoch 20
# loss=6.51042: 100%|██████████| 5/5 [00:08<00:00,  1.76s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
# Test Epoch 20: Acc@1:21.71%: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# INFO:root:Starting epoch 21
# loss=6.43883: 100%|██████████| 5/5 [00:06<00:00,  1.33s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.19s/it]
# Test Epoch 21: Acc@1:17.71%: 100%|██████████| 2/2 [00:02<00:00,  1.05s/it]
# INFO:root:Starting epoch 22
# loss=6.38912: 100%|██████████| 5/5 [00:08<00:00,  1.67s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Test Epoch 22: Acc@1:19.71%: 100%|██████████| 2/2 [00:02<00:00,  1.04s/it]
# INFO:root:Starting epoch 23
# loss=6.34338: 100%|██████████| 5/5 [00:06<00:00,  1.35s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]
# Test Epoch 23: Acc@1:21.14%: 100%|██████████| 2/2 [00:02<00:00,  1.10s/it]
# INFO:root:Starting epoch 24
# loss=6.37321: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.31s/it]
# Test Epoch 24: Acc@1:19.71%: 100%|██████████| 2/2 [00:02<00:00,  1.04s/it]
# INFO:root:Starting epoch 25
# loss=6.42865: 100%|██████████| 5/5 [00:08<00:00,  1.69s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 25: Acc@1:20.57%: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# INFO:root:Starting epoch 26
# loss=6.37803: 100%|██████████| 5/5 [00:08<00:00,  1.63s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.14it/s]
# Test Epoch 26: Acc@1:22.00%: 100%|██████████| 2/2 [00:03<00:00,  1.50s/it]
# INFO:root:Starting epoch 27
# loss=6.30383: 100%|██████████| 5/5 [00:08<00:00,  1.78s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.15it/s]
# Test Epoch 27: Acc@1:18.57%: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# INFO:root:Starting epoch 28
# loss=6.45246: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Test Epoch 28: Acc@1:20.57%: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# INFO:root:Starting epoch 29
# loss=6.38976: 100%|██████████| 5/5 [00:08<00:00,  1.68s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.26s/it]
# Test Epoch 29: Acc@1:20.57%: 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
# INFO:root:Starting epoch 30
# loss=6.36485: 100%|██████████| 5/5 [00:06<00:00,  1.29s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.23s/it]
# Test Epoch 30: Acc@1:21.43%: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# INFO:root:Starting epoch 31
# loss=6.41660: 100%|██████████| 5/5 [00:05<00:00,  1.18s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.06it/s]
# Test Epoch 31: Acc@1:19.14%: 100%|██████████| 2/2 [00:02<00:00,  1.05s/it]
# INFO:root:Starting epoch 32
# loss=6.32493: 100%|██████████| 5/5 [00:06<00:00,  1.24s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 32: Acc@1:20.00%: 100%|██████████| 2/2 [00:02<00:00,  1.07s/it]
# INFO:root:Starting epoch 33
# loss=6.36315: 100%|██████████| 5/5 [00:06<00:00,  1.29s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# Test Epoch 33: Acc@1:20.57%: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# INFO:root:Starting epoch 34
# loss=6.41938: 100%|██████████| 5/5 [00:08<00:00,  1.71s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 34: Acc@1:22.29%: 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# INFO:root:Starting epoch 35
# loss=6.50688: 100%|██████████| 5/5 [00:06<00:00,  1.28s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.04it/s]
# Test Epoch 35: Acc@1:20.29%: 100%|██████████| 2/2 [00:02<00:00,  1.29s/it]
# INFO:root:Starting epoch 36
# loss=6.37307: 100%|██████████| 5/5 [00:06<00:00,  1.32s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Test Epoch 36: Acc@1:20.00%: 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# INFO:root:Starting epoch 37
# loss=6.34037: 100%|██████████| 5/5 [00:06<00:00,  1.30s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# Test Epoch 37: Acc@1:21.14%: 100%|██████████| 2/2 [00:02<00:00,  1.02s/it]
# INFO:root:Starting epoch 38
# loss=6.43834: 100%|██████████| 5/5 [00:08<00:00,  1.79s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# Test Epoch 38: Acc@1:20.00%: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# INFO:root:Starting epoch 39
# loss=6.45497: 100%|██████████| 5/5 [00:06<00:00,  1.23s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# Test Epoch 39: Acc@1:19.14%: 100%|██████████| 2/2 [00:02<00:00,  1.47s/it]
# INFO:root:Starting epoch 40
# loss=6.26040: 100%|██████████| 5/5 [00:06<00:00,  1.22s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.30s/it]
# Test Epoch 40: Acc@1:19.43%: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# INFO:root:Starting epoch 41
# loss=6.41145: 100%|██████████| 5/5 [00:09<00:00,  1.81s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# Test Epoch 41: Acc@1:20.57%: 100%|██████████| 2/2 [00:02<00:00,  1.12s/it]
# INFO:root:Starting epoch 42
# loss=6.31000: 100%|██████████| 5/5 [00:09<00:00,  1.86s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# Test Epoch 42: Acc@1:21.14%: 100%|██████████| 2/2 [00:02<00:00,  1.32s/it]
# INFO:root:Starting epoch 43
# loss=6.32012: 100%|██████████| 5/5 [00:06<00:00,  1.27s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.24s/it]
# Test Epoch 43: Acc@1:22.57%: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# INFO:root:Starting epoch 44
# loss=6.40989: 100%|██████████| 5/5 [00:06<00:00,  1.24s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.25s/it]
# Test Epoch 44: Acc@1:21.43%: 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
# INFO:root:Starting epoch 45
# loss=6.43005: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 45: Acc@1:21.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 46
# loss=6.31327: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 46: Acc@1:22.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 47
# loss=6.33863: 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 47: Acc@1:20.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 48
# loss=6.45928: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 48: Acc@1:21.43%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 49
# loss=6.39942: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 49: Acc@1:21.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 50
# loss=6.33653: 100%|██████████| 5/5 [00:04<00:00,  1.00it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 50: Acc@1:22.86%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 51
# loss=6.37580: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 51: Acc@1:20.00%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 52
# loss=6.37143: 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 52: Acc@1:20.00%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 53
# loss=6.60167: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 53: Acc@1:22.00%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 54
# loss=6.40275: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 54: Acc@1:20.00%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 55
# loss=6.41748: 100%|██████████| 5/5 [00:04<00:00,  1.05it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 55: Acc@1:20.00%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 56
# loss=6.36335: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 56: Acc@1:21.14%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 57
# loss=6.37172: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 57: Acc@1:18.86%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 58
# loss=6.38625: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Test Epoch 58: Acc@1:20.57%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 59
# loss=6.36772: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 59: Acc@1:23.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 60
# loss=6.40363: 100%|██████████| 5/5 [00:06<00:00,  1.35s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 60: Acc@1:23.14%: 100%|██████████| 2/2 [00:01<00:00,  1.05it/s]
# INFO:root:Starting epoch 61
# loss=6.33766: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Test Epoch 61: Acc@1:20.29%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 62
# loss=6.48325: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 62: Acc@1:19.14%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 63
# loss=6.44831: 100%|██████████| 5/5 [00:07<00:00,  1.56s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 63: Acc@1:20.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 64
# loss=6.46427: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 64: Acc@1:21.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 65
# loss=6.43493: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 65: Acc@1:20.86%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 66
# loss=6.50564: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 66: Acc@1:20.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 67
# loss=6.45758: 100%|██████████| 5/5 [00:04<00:00,  1.12it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 67: Acc@1:21.14%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 68
# loss=6.42188: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 68: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 69
# loss=6.52183: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 69: Acc@1:23.71%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 70
# loss=6.34104: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Test Epoch 70: Acc@1:22.86%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 71
# loss=6.43182: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 71: Acc@1:20.29%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 72
# loss=6.38747: 100%|██████████| 5/5 [00:07<00:00,  1.56s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 72: Acc@1:21.14%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 73
# loss=6.44750: 100%|██████████| 5/5 [00:07<00:00,  1.50s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 73: Acc@1:22.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 74
# loss=6.49893: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 74: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 75
# loss=6.48412: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 75: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 76
# loss=6.32495: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 76: Acc@1:22.00%: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# INFO:root:Starting epoch 77
# loss=6.44376: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 77: Acc@1:21.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 78
# loss=6.32735: 100%|██████████| 5/5 [00:04<00:00,  1.16it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 78: Acc@1:20.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 79
# loss=6.43726: 100%|██████████| 5/5 [00:04<00:00,  1.05it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 79: Acc@1:22.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 80
# loss=6.40429: 100%|██████████| 5/5 [00:08<00:00,  1.68s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 80: Acc@1:22.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 81
# loss=6.48987: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 81: Acc@1:23.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 82
# loss=6.46441: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Test Epoch 82: Acc@1:20.86%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 83
# loss=6.48015: 100%|██████████| 5/5 [00:04<00:00,  1.00it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 83: Acc@1:23.14%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 84
# loss=6.41011: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 84: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 85
# loss=6.41266: 100%|██████████| 5/5 [00:05<00:00,  1.03s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 85: Acc@1:21.71%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 86
# loss=6.69494: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 86: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 87
# loss=6.35662: 100%|██████████| 5/5 [00:05<00:00,  1.06s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 87: Acc@1:23.14%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 88
# loss=6.33802: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 88: Acc@1:24.00%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 89
# loss=6.43833: 100%|██████████| 5/5 [00:04<00:00,  1.00it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 89: Acc@1:26.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 90
# loss=6.41863: 100%|██████████| 5/5 [00:04<00:00,  1.05it/s]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Test Epoch 90: Acc@1:23.71%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 91
# loss=6.54801: 100%|██████████| 5/5 [00:04<00:00,  1.15it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 91: Acc@1:24.00%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 92
# loss=6.37364: 100%|██████████| 5/5 [00:04<00:00,  1.14it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 92: Acc@1:24.00%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 93
# loss=6.34130: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Test Epoch 93: Acc@1:24.00%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 94
# loss=6.31924: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 94: Acc@1:23.71%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 95
# loss=6.50616: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 95: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 96
# loss=6.48585: 100%|██████████| 5/5 [00:05<00:00,  1.00s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 96: Acc@1:23.14%: 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# INFO:root:Starting epoch 97
# loss=6.42667: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 97: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 98
# loss=6.40238: 100%|██████████| 5/5 [00:04<00:00,  1.05it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 98: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 99
# loss=6.54076: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 99: Acc@1:23.71%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 100
# loss=6.47798: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Test Epoch 100: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 101
# loss=6.29013: 100%|██████████| 5/5 [00:04<00:00,  1.13it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 101: Acc@1:25.71%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 102
# loss=6.25076: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 102: Acc@1:26.00%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 103
# loss=6.43494: 100%|██████████| 5/5 [00:04<00:00,  1.05it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 103: Acc@1:26.00%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 104
# loss=6.28967: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 104: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 105
# loss=6.33614: 100%|██████████| 5/5 [00:04<00:00,  1.13it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 105: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# INFO:root:Starting epoch 106
# loss=6.38567: 100%|██████████| 5/5 [00:05<00:00,  1.00s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 106: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 107
# loss=6.40244: 100%|██████████| 5/5 [00:05<00:00,  1.16s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Test Epoch 107: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 108
# loss=6.28813: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 108: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 109
# loss=6.33138: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 109: Acc@1:23.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 110
# loss=6.38412: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 110: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 111
# loss=6.29227: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 111: Acc@1:26.86%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 112
# loss=6.30154: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 112: Acc@1:25.71%: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# INFO:root:Starting epoch 113
# loss=6.51618: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 113: Acc@1:26.00%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 114
# loss=6.50358: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Test Epoch 114: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 115
# loss=6.27909: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 115: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 116
# loss=6.37061: 100%|██████████| 5/5 [00:05<00:00,  1.00s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 116: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 117
# loss=6.38827: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
# Test Epoch 117: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 118
# loss=6.26720: 100%|██████████| 5/5 [00:07<00:00,  1.49s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 118: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 119
# loss=6.36464: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 119: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 120
# loss=6.39144: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 120: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 121
# loss=6.44422: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.24it/s]
# Test Epoch 121: Acc@1:24.57%: 100%|██████████| 2/2 [00:02<00:00,  1.05s/it]
# INFO:root:Starting epoch 122
# loss=6.31715: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 122: Acc@1:26.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 123
# loss=6.44654: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 123: Acc@1:26.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 124
# loss=6.40050: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.16s/it]
# Test Epoch 124: Acc@1:23.71%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 125
# loss=6.23538: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Test Epoch 125: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 126
# loss=6.24881: 100%|██████████| 5/5 [00:05<00:00,  1.07s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 126: Acc@1:25.71%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 127
# loss=6.25952: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 127: Acc@1:23.71%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 128
# loss=6.40201: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 128: Acc@1:24.00%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 129
# loss=6.31167: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 129: Acc@1:26.00%: 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# INFO:root:Starting epoch 130
# loss=6.12123: 100%|██████████| 5/5 [00:08<00:00,  1.72s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Test Epoch 130: Acc@1:27.43%: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# INFO:root:Starting epoch 131
# loss=6.43909: 100%|██████████| 5/5 [00:05<00:00,  1.00s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Test Epoch 131: Acc@1:26.29%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 132
# loss=6.36301: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Test Epoch 132: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 133
# loss=6.24057: 100%|██████████| 5/5 [00:07<00:00,  1.51s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Test Epoch 133: Acc@1:25.14%: 100%|██████████| 2/2 [00:02<00:00,  1.22s/it]
# INFO:root:Starting epoch 134
# loss=6.27283: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 134: Acc@1:23.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 135
# loss=6.40229: 100%|██████████| 5/5 [00:05<00:00,  1.03s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 135: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 136
# loss=6.25984: 100%|██████████| 5/5 [00:05<00:00,  1.07s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 136: Acc@1:25.71%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 137
# loss=6.35180: 100%|██████████| 5/5 [00:05<00:00,  1.14s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 137: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 138
# loss=6.29624: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 138: Acc@1:26.00%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 139
# loss=6.25144: 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 139: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 140
# loss=6.35790: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]
# Test Epoch 140: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 141
# loss=6.35469: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 141: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 142
# loss=6.25151: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 142: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 143
# loss=6.35156: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 143: Acc@1:25.71%: 100%|██████████| 2/2 [00:01<00:00,  1.06it/s]
# INFO:root:Starting epoch 144
# loss=6.29401: 100%|██████████| 5/5 [00:04<00:00,  1.05it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 144: Acc@1:26.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 145
# loss=6.35590: 100%|██████████| 5/5 [00:07<00:00,  1.51s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 145: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 146
# loss=6.21365: 100%|██████████| 5/5 [00:08<00:00,  1.64s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Test Epoch 146: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# INFO:root:Starting epoch 147
# loss=6.49614: 100%|██████████| 5/5 [00:05<00:00,  1.04s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 147: Acc@1:26.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 148
# loss=6.31211: 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 148: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 149
# loss=6.46664: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 149: Acc@1:26.00%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 150
# loss=6.23073: 100%|██████████| 5/5 [00:04<00:00,  1.13it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 150: Acc@1:26.29%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 151
# loss=6.34044: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 151: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 152
# loss=6.25059: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Test Epoch 152: Acc@1:26.00%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 153
# loss=6.30112: 100%|██████████| 5/5 [00:05<00:00,  1.09s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Test Epoch 153: Acc@1:25.71%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 154
# loss=6.30769: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Test Epoch 154: Acc@1:26.00%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 155
# loss=6.26134: 100%|██████████| 5/5 [00:05<00:00,  1.11s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 155: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# INFO:root:Starting epoch 156
# loss=6.09999: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
# Test Epoch 156: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# INFO:root:Starting epoch 157
# loss=6.33203: 100%|██████████| 5/5 [00:05<00:00,  1.00s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 157: Acc@1:26.29%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 158
# loss=6.31669: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.33it/s]
# Test Epoch 158: Acc@1:24.00%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 159
# loss=6.32051: 100%|██████████| 5/5 [00:04<00:00,  1.13it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 159: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 160
# loss=6.41415: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 160: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 161
# loss=6.45277: 100%|██████████| 5/5 [00:05<00:00,  1.03s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 161: Acc@1:25.71%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 162
# loss=6.41785: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
# Test Epoch 162: Acc@1:25.71%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 163
# loss=6.39895: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 163: Acc@1:26.57%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 164
# loss=6.24791: 100%|██████████| 5/5 [00:04<00:00,  1.00it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# Test Epoch 164: Acc@1:26.29%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 165
# loss=6.31549: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 165: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 166
# loss=6.60254: 100%|██████████| 5/5 [00:08<00:00,  1.60s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 166: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 167
# loss=6.21777: 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 167: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 168
# loss=6.49400: 100%|██████████| 5/5 [00:04<00:00,  1.09it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 168: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 169
# loss=6.39544: 100%|██████████| 5/5 [00:05<00:00,  1.06s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 169: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 170
# loss=6.47248: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 170: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 171
# loss=6.37418: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 171: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 172
# loss=6.30611: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 172: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 173
# loss=6.39775: 100%|██████████| 5/5 [00:07<00:00,  1.53s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 173: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 174
# loss=6.25722: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 174: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 175
# loss=6.39815: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 175: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 176
# loss=6.31646: 100%|██████████| 5/5 [00:05<00:00,  1.08s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 176: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 177
# loss=6.53143: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 177: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 178
# loss=6.26959: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# Test Epoch 178: Acc@1:24.29%: 100%|██████████| 2/2 [00:02<00:00,  1.37s/it]
# INFO:root:Starting epoch 179
# loss=6.28200: 100%|██████████| 5/5 [00:04<00:00,  1.03it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Test Epoch 179: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# INFO:root:Starting epoch 180
# loss=6.40944: 100%|██████████| 5/5 [00:05<00:00,  1.07s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 180: Acc@1:24.29%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 181
# loss=6.22188: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 181: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 182
# loss=6.52959: 100%|██████████| 5/5 [00:04<00:00,  1.07it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 182: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 183
# loss=6.41814: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 183: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 184
# loss=6.54311: 100%|██████████| 5/5 [00:04<00:00,  1.02it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 184: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 185
# loss=6.31339: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 185: Acc@1:25.14%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 186
# loss=6.50488: 100%|██████████| 5/5 [00:04<00:00,  1.06it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 186: Acc@1:26.00%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 187
# loss=6.39268: 100%|██████████| 5/5 [00:04<00:00,  1.10it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 187: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.07it/s]
# INFO:root:Starting epoch 188
# loss=6.36951: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 188: Acc@1:25.43%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 189
# loss=6.50721: 100%|██████████| 5/5 [00:05<00:00,  1.01s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 189: Acc@1:25.71%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 190
# loss=6.59688: 100%|██████████| 5/5 [00:05<00:00,  1.05s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 190: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 191
# loss=6.48009: 100%|██████████| 5/5 [00:04<00:00,  1.08it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 191: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 192
# loss=6.25787: 100%|██████████| 5/5 [00:07<00:00,  1.40s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# Test Epoch 192: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 193
# loss=6.58501: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# Test Epoch 193: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 194
# loss=6.49278: 100%|██████████| 5/5 [00:04<00:00,  1.04it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# Test Epoch 194: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 195
# loss=6.55983: 100%|██████████| 5/5 [00:05<00:00,  1.03s/it]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Test Epoch 195: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 196
# loss=6.40138: 100%|██████████| 5/5 [00:05<00:00,  1.02s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 196: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 197
# loss=6.53132: 100%|██████████| 5/5 [00:05<00:00,  1.00s/it]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.32it/s]
# Test Epoch 197: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.11it/s]
# INFO:root:Starting epoch 198
# loss=6.60531: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 198: Acc@1:24.86%: 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# INFO:root:Starting epoch 199
# loss=6.56750: 100%|██████████| 5/5 [00:04<00:00,  1.12it/s]
# Feature extracting: 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# Test Epoch 199: Acc@1:24.57%: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# INFO:root:Starting epoch 200
# loss=6.45943: 100%|██████████| 5/5 [00:04<00:00,  1.01it/s]
# Feature extracting: 100%|██████████| 2/2 [00:02<00:00,  1.15s/it]
# Test Epoch 200: Acc@1:24.57%: 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]

# %%
import pandas as pd
import matplotlib.pyplot as plt
accuracy_df = pd.read_csv('example_logs/accuracy.csv')
accuracy = accuracy_df['knn_monitor_accuracy']
plt.plot(accuracy)

plt.title('KNN Monitored Accuracy Plot')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')

plt.show()

# %%
loss_df = pd.read_csv('example_logs/loss_histories.csv')
loss = loss_df['loss']
plt.plot(loss)

plt.title('Loss Plot')
plt.xlabel('Iteration')
plt.ylabel('Loss')

plt.show()
